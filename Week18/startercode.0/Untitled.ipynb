# %%
import pandas as pd
import numpy as np

i = pd.Series([4,6,0,7,8,1,2,10,9,3,5,11])

feature_importances = pd.Series([0.661344,0.203801,0.038353,0.027453,0.016288,0.014203,\
                                0.013851,0.011136,0.008183,0.003772,0.001617,0.000000])

feature_names = pd.Series(['chlorides','total sulfur dioxide','fixed acidity','density',\
                           'pH','volatile acidity','citric acid','alcohol','sulphates',\
                           'residual sugar','free sulfur dioxide','quality'])

frame = { 'feature_importances': feature_importances, 'feature_names': feature_names} 
  
df = pd.DataFrame(frame) 



df.index = [4,6,0,7,8,1,2,10,9,3,5,11]

# %%
df
# Out:
#     feature_importances         feature_names
# 4              0.661344             chlorides
# 6              0.203801  total sulfur dioxide
# 0              0.038353         fixed acidity
# 7              0.027453               density
# 8              0.016288                    pH
# 1              0.014203      volatile acidity
# 2              0.013851           citric acid
# 10             0.011136               alcohol
# 9              0.008183             sulphates
# 3              0.003772        residual sugar
# 5              0.001617   free sulfur dioxide
# 11             0.000000               quality
