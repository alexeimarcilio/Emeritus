# %% [markdown]
# # Week 12: tbd

# %% [markdown]
# $$
# {\displaystyle f(x)={\frac {1}{\sigma {\sqrt {2\pi }}}}e^{-{\frac {1}{2}}\left({\frac {x-\mu }{\sigma }}\right)^{2}}} $$

# %%
import numpy as np
def f(x):
    frac = 1/(sigma*np.sqrt(2*np.pi))
    exp = -1/2*((x - mu)/sigma)**2
    return frac*np.e**exp

# %%
mu = 0
sigma = 1

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(np.random.normal(0, 1, 100))

# %%
def plot_normal(mu, sigma):
    s = np.random.normal(mu, sigma, 1000)
    count, bins, ignored = plt.hist(s, 30, density=True)
    plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *np.exp( - (bins - mu)**2 / (2 * sigma**2) ),linewidth=2, color='r')

# %%
plot_normal(0, 1)

# %%
outcomes = []
coin = [0, 1]
for i in range(100):
    flip = np.random.choice(coin, size = 1000)
    outcomes.append(sum(flip)/100)

# %%
#plt.plot(outcomes)

# %%
from ipywidgets import interact 
import ipywidgets as widgets

# %%
def coin_plotter(n):
    outcomes = []
    coin = [0, 1]
    for i in range(n):
        flip = np.random.choice(coin, size = 1000)
        outcomes.append(sum(flip)/1000)
    plt.hist(np.sort(outcomes))

# %%
interact(coin_plotter, n = widgets.IntSlider(min = 10, max = 100_000, step = 10))
# Out:
# interactive(children=(IntSlider(value=10, description='n', max=100000, min=10, step=10), Output()), _dom_class…
# <function __main__.coin_plotter(n)>
