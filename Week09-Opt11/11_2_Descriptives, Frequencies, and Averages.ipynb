# %% [markdown]
# # Descriptives, Frequencies, and Averages

# %% [markdown]
# # Outline
# - Descriptives statistics
# - Frequencies
# - Mean, standard deviation, and median

# %%
import pandas as pd
import numpy as np
social = pd.read_csv('social_cleaned.csv')

# %%
social
# Out:
#       Unnamed: 0  respid  sex  eminuse  intmob  intfreq home4nw bbhome1  \
# 0              0       1    2        1       1      1.0       1       2
# 1              1       2    2        2       2      NaN
# 2              2       3    2        1       2      3.0       1       2
# 3              3       4    2        1       1      4.0       1       2
# 4              5       5    1        1       1      2.0       1       2
# ...          ...     ...  ...      ...     ...      ...     ...     ...
# 1997        1998  102425    1        1       1      2.0       1       2
# 1998        1999  102426    1        1       1      1.0       1       2
# 1999        2000  102427    2        1       1      4.0       1       2
# 2000        2001  102429    1        1       2      2.0       1       2
# 2001        2002  102430    1        1       1      1.0       2
#
#      bbhome2 device1a  ... hisp  racem1  racem2  racem3  racem4 racecmb  \
# ...

# %% [markdown]
# ## Descriptive Statistics

# %%
social.describe()
# Out:
#         Unnamed: 0         respid          sex      eminuse       intmob  \
# count  2002.000000    2002.000000  2002.000000  2002.000000  2002.000000
# mean   1001.498002   76009.782717     1.460040     1.139361     1.187812
# std     578.075395   43691.053230     0.498525     0.375485     0.486388
# min       0.000000       1.000000     1.000000     1.000000     1.000000
# 25%     501.250000  100004.000000     1.000000     1.000000     1.000000
# 50%    1001.500000  100819.000000     1.000000     1.000000     1.000000
# 75%    1501.750000  101577.500000     2.000000     1.000000     1.000000
# max    2002.000000  102430.000000     2.000000     8.000000     8.000000
#
#            intfreq      snsint2     device1b     device1c     device1d  ...  \
# count  1781.000000  2002.000000  2002.000000  2002.000000  2002.000000  ...
# mean      2.140371     1.338162     1.487013     1.247253     1.676324  ...
# std       1.091053     0.535620     0.651820     0.455194     0.593256  ...
# ...

# %%
social['intfreq'].describe()
# Out:
# count    1781.000000
# mean        2.140371
# std         1.091053
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         5.000000
# Name: intfreq, dtype: float64

# %% [markdown]
# ## Frequencies

# %%
social['intfreq'].count()
# Out:
# 1781

# %%
social['intfreq'].value_counts()
# Out:
# 2.0    884
# 1.0    496
# 3.0    167
# 4.0    123
# 5.0    111
# Name: intfreq, dtype: int64

# %% [markdown]
# ## Mean, standard deviation, and median

# %%
np.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-0c998bb62981> in <module>
# ----> 1 np.mean()
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# TypeError: _mean_dispatcher() missing 1 required positional argument: 'a'

# %%
np.std()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-d6cb6c6a8b2d> in <module>
# ----> 1 np.std()
#
# <__array_function__ internals> in std(*args, **kwargs)
#
# TypeError: _std_dispatcher() missing 1 required positional argument: 'a'

# %%
np.median()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-eba05ef23d15> in <module>
# ----> 1 np.median()
#
# <__array_function__ internals> in median(*args, **kwargs)
#
# TypeError: _median_dispatcher() missing 1 required positional argument: 'a'

# %%
np.nanmedian()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-dd50975d9cef> in <module>
# ----> 1 np.nanmedian()
#
# <__array_function__ internals> in nanmedian(*args, **kwargs)
#
# TypeError: _nanmedian_dispatcher() missing 1 required positional argument: 'a'

# %% [markdown]
# # Employee Attrition

# %%
df = pd.read_csv("employee_attrition.csv")

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate  DistanceFromHome  \
# 0      41       Yes      Travel_Rarely       1102                 1
# 1      49        No  Travel_Frequently        279                 8
# 2      37       Yes      Travel_Rarely       1373                 2
# 3      33        No  Travel_Frequently       1392                 3
# 4      27        No      Travel_Rarely        591                 2
# ...   ...       ...                ...        ...               ...
# 1465   36        No  Travel_Frequently        884                23
# 1466   39        No      Travel_Rarely        613                 6
# 1467   27        No      Travel_Rarely        155                 4
# 1468   49        No  Travel_Frequently       1023                 2
# 1469   34        No      Travel_Rarely        628                 8
#
#       EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %% [markdown]
# ## Descriptive Statistics

# %%
# Handling floats because 2 decimal places is easier to read. In your analyis you may need more
pd.options.display.float_format = "{:,.2f}".format

# %%
df.describe()
# Out:
#            Age  DailyRate  DistanceFromHome  EnvironmentSatisfaction  \
# count 1,470.00   1,470.00          1,470.00                 1,470.00
# mean     36.92     802.49              9.19                     2.72
# std       9.14     403.51              8.11                     1.09
# min      18.00     102.00              1.00                     1.00
# 25%      30.00     465.00              2.00                     2.00
# 50%      36.00     802.00              7.00                     3.00
# 75%      43.00   1,157.00             14.00                     4.00
# max      60.00   1,499.00             29.00                     4.00
#
#        HourlyRate  JobInvolvement  JobLevel  JobSatisfaction  MonthlyIncome  \
# count    1,470.00        1,470.00  1,470.00         1,470.00       1,470.00
# mean        65.89            2.73      2.06             2.73       6,502.93
# std         20.33            0.71      1.11             1.10       4,707.96
# ...

# %%
df['Age'].describe()
# Out:
# count   1,470.00
# mean       36.92
# std         9.14
# min        18.00
# 25%        30.00
# 50%        36.00
# 75%        43.00
# max        60.00
# Name: Age, dtype: float64

# %%
df['Age'].value_counts()
# Out:
# 35    78
# 34    77
# 31    69
# 36    69
# 29    68
# 32    61
# 30    60
# 33    58
# 38    58
# 40    57
# 37    50
# 27    48
# 28    48
# 42    46
# 39    42
# 45    41
# 41    40
# 26    39
# 46    33
# 44    33
# 43    32
# 50    30
# 24    26
# 25    26
# 47    24
# 49    24
# 55    22
# 48    19
# 51    19
# 53    19
# 52    18
# 54    18
# 22    16
# 56    14
# 58    14
# 23    14
# 21    13
# 20    11
# 59    10
# 19     9
# 18     8
# 60     5
# 57     4
# Name: Age, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))
sns.countplot(y=df['Age'])

# %%
# For a smaller number of unique entries we can look at value counts for 
# each of the columns
# Can use this in the future
# Better than typing each variable
object_col = []
for column in df.columns:
    if df[column].dtype == object and len(df[column].unique()) <= 30:
        object_col.append(column)
        print(f"{column} : {df[column].unique()}")
        print(df[column].value_counts())
        print("*********************************")
# Out:
# Attrition : ['Yes' 'No']
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
# *********************************
# BusinessTravel : ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# *********************************
# Gender : ['Female' 'Male']
# Male      882
# Female    588
# Name: Gender, dtype: int64
# *********************************
# MaritalStatus : ['Single' 'Married' 'Divorced']
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64
# *********************************
# OverTime : ['Yes' 'No']
# No     1054
# Yes     416
# Name: OverTime, dtype: int64
# *********************************

# %%
for column in df.columns:
    print(f"column: {column}: Number of unique values: {df[column].nunique()}")
# Out:
# column: Age: Number of unique values: 43
# column: Attrition: Number of unique values: 2
# column: BusinessTravel: Number of unique values: 3
# column: DailyRate: Number of unique values: 886
# column: DistanceFromHome: Number of unique values: 29
# column: EnvironmentSatisfaction: Number of unique values: 4
# column: Gender: Number of unique values: 2
# column: HourlyRate: Number of unique values: 71
# column: JobInvolvement: Number of unique values: 4
# column: JobLevel: Number of unique values: 5
# column: JobSatisfaction: Number of unique values: 4
# column: MaritalStatus: Number of unique values: 3
# column: MonthlyIncome: Number of unique values: 1349
# column: NumCompaniesWorked: Number of unique values: 10
# column: OverTime: Number of unique values: 2
# column: PercentSalaryHike: Number of unique values: 15
# column: PerformanceRating: Number of unique values: 2
# column: RelationshipSatisfaction: Number of unique values: 4
# ...

# %%
for column in df.columns:
    if df[column].dtype == object and len(df[column].unique()) <= 30:
        sns.countplot(df[column])

# %%
object_col
# Out:
# ['Attrition', 'BusinessTravel', 'Gender', 'MaritalStatus', 'OverTime']

# %%
#df=pd.DataFrame(np.random.choice(list("abcd"), size=(100,20), p=[.4,.3,.2,.1]))

#plt.figure(figsize=(30, 30))
#df[object_col].apply(pd.value_counts).plot(kind="bar", subplots=False, layout=(len(object_col),1), legend=False)


for item in object_col:
    df[item].value_counts().plot(kind='bar')
#plt.tight_layout() 

#plt.show()

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate  DistanceFromHome  \
# 0      41       Yes      Travel_Rarely       1102                 1
# 1      49        No  Travel_Frequently        279                 8
# 2      37       Yes      Travel_Rarely       1373                 2
# 3      33        No  Travel_Frequently       1392                 3
# 4      27        No      Travel_Rarely        591                 2
# ...   ...       ...                ...        ...               ...
# 1465   36        No  Travel_Frequently        884                23
# 1466   39        No      Travel_Rarely        613                 6
# 1467   27        No      Travel_Rarely        155                 4
# 1468   49        No  Travel_Frequently       1023                 2
# 1469   34        No      Travel_Rarely        628                 8
#
#       EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate  DistanceFromHome  \
# 0      41       Yes      Travel_Rarely       1102                 1
# 1      49        No  Travel_Frequently        279                 8
# 2      37       Yes      Travel_Rarely       1373                 2
# 3      33        No  Travel_Frequently       1392                 3
# 4      27        No      Travel_Rarely        591                 2
# ...   ...       ...                ...        ...               ...
# 1465   36        No  Travel_Frequently        884                23
# 1466   39        No      Travel_Rarely        613                 6
# 1467   27        No      Travel_Rarely        155                 4
# 1468   49        No  Travel_Frequently       1023                 2
# 1469   34        No      Travel_Rarely        628                 8
#
#       EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
# Find all the categorical features
object_col = []
for column in df.columns:
    if df[column].dtype == object and len(df[column].unique()) <= 5:
        object_col.append(column)


# %matplotlib inline
        
fig, ax = plt.subplots(1, len(object_col), figsize=(20,5))
for i, object_col in enumerate(df[object_col]):
    df[object_col].value_counts().plot(kind="bar", ax=ax[i]).set_title(object_col)
#fig.show();

# %%
df['BusinessTravel'].value_counts().plot(kind="bar")

# %%
df.describe()
# Out:
#            Age  DailyRate  DistanceFromHome  EnvironmentSatisfaction  \
# count 1,470.00   1,470.00          1,470.00                 1,470.00
# mean     36.92     802.49              9.19                     2.72
# std       9.14     403.51              8.11                     1.09
# min      18.00     102.00              1.00                     1.00
# 25%      30.00     465.00              2.00                     2.00
# 50%      36.00     802.00              7.00                     3.00
# 75%      43.00   1,157.00             14.00                     4.00
# max      60.00   1,499.00             29.00                     4.00
#
#        HourlyRate  JobInvolvement  JobLevel  JobSatisfaction  MonthlyIncome  \
# count    1,470.00        1,470.00  1,470.00         1,470.00       1,470.00
# mean        65.89            2.73      2.06             2.73       6,502.93
# std         20.33            0.71      1.11             1.10       4,707.96
# ...
