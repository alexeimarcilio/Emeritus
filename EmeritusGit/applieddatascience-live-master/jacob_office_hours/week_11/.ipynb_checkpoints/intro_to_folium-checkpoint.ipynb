# %% [markdown]
# ### Plotting and Mapping

# %%
import pandas as pd

# %%
nyc_311 = pd.read_json('https://data.cityofnewyork.us/resource/erm2-nwe9.json')

# %%
nyc_311.head()
# Out:
#    unique_key             created_date agency  \
# 0    46560392  2020-06-21T02:00:06.000   NYPD
# 1    46552132  2020-06-21T01:59:59.000   NYPD
# 2    46550580  2020-06-21T01:59:52.000   NYPD
# 3    46550850  2020-06-21T01:59:46.000   NYPD
# 4    46551337  2020-06-21T01:59:45.000   NYPD
#
#                        agency_name           complaint_type        descriptor  \
# 0  New York City Police Department          Noise - Vehicle   Car/Truck Music
# 1  New York City Police Department         Blocked Driveway         No Access
# 2  New York City Police Department        Illegal Fireworks               N/A
# 3  New York City Police Department        Illegal Fireworks               N/A
# 4  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
#
#                 location_type  incident_zip   incident_address  \
# 0             Street/Sidewalk       10453.0  51 BUCHANAN PLACE
# 1             Street/Sidewalk           NaN                NaN
# 2  Residential Building/House       10040.0  44 SICKLES STREET
# 3             Street/Sidewalk       11208.0     BELMONT AVENUE
# 4             Street/Sidewalk           NaN                NaN
#
#       street_name  ...  longitude  \
# 0  BUCHANAN PLACE  ... -73.906294
# 1             NaN  ...        NaN
# 2  SICKLES STREET  ... -73.927873
# 3  BELMONT AVENUE  ... -73.875879
# 4             NaN  ...        NaN
#
#                                             location  \
# 0  {'latitude': '40.858417348800984', 'longitude'...
# 1                                                NaN
# 2  {'latitude': '40.86147398456526', 'longitude':...
# 3  {'latitude': '40.673516481488825', 'longitude'...
# 4                                                NaN
#
#   :@computed_region_efsh_h5xi :@computed_region_f5dn_yrer  \
# 0                     10931.0                         6.0
# 1                         NaN                         NaN
# 2                     13098.0                        47.0
# 3                     17215.0                        45.0
# 4                         NaN                         NaN
#
#   :@computed_region_yeji_bk3q :@computed_region_92fq_4b7q  \
# 0                         5.0                        29.0
# 1                         NaN                         NaN
# 2                         4.0                        39.0
# 3                         2.0                        25.0
# 4                         NaN                         NaN
#
#   :@computed_region_sbqj_enih resolution_description  \
# 0                        29.0                    NaN
# 1                         NaN                    NaN
# 2                        22.0                    NaN
# 3                        47.0                    NaN
# 4                         NaN                    NaN
#
#    resolution_action_updated_date closed_date
# 0                             NaN         NaN
# 1                             NaN         NaN
# 2                             NaN         NaN
# 3                             NaN         NaN
# 4                             NaN         NaN
#
# [5 rows x 36 columns]

# %%
# import pandas as pd
# from sodapy import Socrata

# # Unauthenticated client only works with public data sets. Note 'None'
# # in place of application token, and no username or password:
# client = Socrata("data.cityofnewyork.us", None)

# # Example authenticated client (needed for non-public datasets):
# # client = Socrata(data.cityofnewyork.us,
# #                  MyAppToken,
# #                  userame="user@example.com",
# #                  password="AFakePassword")

# # First 2000 results, returned as JSON from API / converted to Python list of
# # dictionaries by sodapy.
# results = client.get("erm2-nwe9", limit=20)

# # Convert to pandas DataFrame
# results_df = pd.DataFrame.from_records(results)

# %%
locations = nyc_311.loc[:, ['latitude', 'longitude']]

# %%
locations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   latitude   992 non-null    float64
#  1   longitude  992 non-null    float64
# dtypes: float64(2)
# memory usage: 15.8 KB

# %%
locations
# Out:
#       latitude  longitude
# 0    40.858417 -73.906294
# 1          NaN        NaN
# 2    40.861474 -73.927873
# 3    40.673516 -73.875879
# 4          NaN        NaN
# ..         ...        ...
# 995  40.831529 -73.922568
# 996  40.844351 -73.933653
# 997  40.710927 -73.951341
# 998  40.690783 -73.812433
# 999  40.815080 -73.873914
#
# [1000 rows x 2 columns]

# %%
import folium

# %%
start_location = locations.iloc[0]

# %%
#!pip install folium

# %%
m = folium.Map(start_location, zoom_start=14)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
nyc_311.columns
# Out:
# Index(['unique_key', 'created_date', 'agency', 'agency_name', 'complaint_type',
#        'descriptor', 'location_type', 'incident_zip', 'incident_address',
#        'street_name', 'cross_street_1', 'cross_street_2',
#        'intersection_street_1', 'intersection_street_2', 'city', 'landmark',
#        'status', 'community_board', 'bbl', 'borough',
#        'x_coordinate_state_plane', 'y_coordinate_state_plane',
#        'open_data_channel_type', 'park_facility_name', 'park_borough',
#        'latitude', 'longitude', 'location', ':@computed_region_efsh_h5xi',
#        ':@computed_region_f5dn_yrer', ':@computed_region_yeji_bk3q',
#        ':@computed_region_92fq_4b7q', ':@computed_region_sbqj_enih',
#        'resolution_description', 'resolution_action_updated_date',
#        'closed_date'],
#       dtype='object')

# %%
cols = ['agency_name', 'complaint_type', 'borough', 'latitude', 'longitude']
df = nyc_311.loc[:, cols]

# %%
df.head()
# Out:
#                        agency_name           complaint_type      borough  \
# 0  New York City Police Department          Noise - Vehicle        BRONX
# 1  New York City Police Department         Blocked Driveway  Unspecified
# 2  New York City Police Department        Illegal Fireworks    MANHATTAN
# 3  New York City Police Department        Illegal Fireworks     BROOKLYN
# 4  New York City Police Department  Noise - Street/Sidewalk  Unspecified
#
#     latitude  longitude
# 0  40.858417 -73.906294
# 1        NaN        NaN
# 2  40.861474 -73.927873
# 3  40.673516 -73.875879
# 4        NaN        NaN

# %%
popup = f'<strong>Department:</strong>{df.iloc[0, 0]}\n\n<strong>Complaint Type:</strong>{df.iloc[0, 1]}'

marker = folium.CircleMarker(start_location, popup = popup)

# %%
marker.add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df.head()
# Out:
#                        agency_name           complaint_type      borough  \
# 0  New York City Police Department          Noise - Vehicle        BRONX
# 1  New York City Police Department         Blocked Driveway  Unspecified
# 2  New York City Police Department        Illegal Fireworks    MANHATTAN
# 3  New York City Police Department        Illegal Fireworks     BROOKLYN
# 4  New York City Police Department  Noise - Street/Sidewalk  Unspecified
#
#     latitude  longitude
# 0  40.858417 -73.906294
# 1        NaN        NaN
# 2  40.861474 -73.927873
# 3  40.673516 -73.875879
# 4        NaN        NaN

# %%
noise = {'Noise - Street/Sidewalk', 'Noise - Residential', 'Noise - Vehicle'}
fire = {'Illegal Fireworks'}
cars = {'Illegal Parking', 'Blocked Driveway', 'Abandoned Vehicle'}
covid = {'NonCompliance with Phased Reopening'}

def color_mapper(x):
    if x in noise:
        return 'red'
    elif x in fire:
        return 'yellow'
    elif x in cars:
        return 'blue'
    elif x in covid:
        return 'purple'
    else:
        return 'green'
    
df['colors'] = df.complaint_type.apply(color_mapper)

# %%
m = folium.Map(location=start_location, tiles = "StamenWatercolor")
def test_apply(x):
    popup = f'<strong>Department:</strong>{x[0]}\n\n<strong>Complaint Type:</strong>{x[1]}'
    folium.CircleMarker(location=[x[3], x[4]], popup = popup, color = x[-1], fill = True).add_to(m)

# %%
df.dropna(subset = ['latitude', 'longitude']).apply(test_apply, axis = 1)
# Out:
# 0      None
# 2      None
# 3      None
# 5      None
# 6      None
#        ...
# 995    None
# 996    None
# 997    None
# 998    None
# 999    None
# Length: 992, dtype: object

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df.complaint_type.value_counts()
# Out:
# Noise - Street/Sidewalk                358
# Noise - Residential                    305
# Illegal Fireworks                      187
# Noise - Vehicle                         63
# Illegal Parking                         18
# Non-Emergency Police Matter             16
# Noise - Commercial                      14
# Blocked Driveway                        11
# Noise - Park                             7
# Rodent                                   4
# Urinating in Public                      3
# Bike/Roller/Skate Chronic                2
# NonCompliance with Phased Reopening      2
# Homeless Street Condition                2
# Drinking                                 2
# Abandoned Vehicle                        2
# Street Condition                         1
# Indoor Air Quality                       1
# Drug Activity                            1
# Animal-Abuse                             1
# Name: complaint_type, dtype: int64

# %%
noise = {'Noise - Street/Sidewalk', 'Noise - Residential', 'Noise - Vehicle'}
fire = {'Illegal Fireworks'}
cars = {'Illegal Parking', 'Blocked Driveway', 'Abandoned Vehicle'}
covid = {'NonCompliance with Phased Reopening'}

def color_mapper(x):
    if x in noise:
        return 'red'
    elif x in fire:
        return 'yellow'
    elif x in cars:
        return 'blue'
    elif x in covid:
        return 'purple'
    else:
        return 'green'

# %%
police = pd.read_json('https://data.cityofnewyork.us/resource/qgea-i56i.json')

# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("qgea-i56i", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df.head()
# Out:
#   cmplnt_num             cmplnt_fr_dt cmplnt_fr_tm addr_pct_cd  \
# 0  876525802  2008-04-10T00:00:00.000     19:10:00          73
# 1  402693528  2007-06-03T00:00:00.000     15:23:00          28
# 2  832030069  2010-02-16T00:00:00.000     20:50:00         102
# 3  538308771  2009-11-10T00:00:00.000     16:35:00          79
# 4  965693192  2006-04-11T00:00:00.000     09:30:00         123
#
#                     rpt_dt ky_cd          ofns_desc pd_cd  \
# 0  2008-04-10T00:00:00.000   341      PETIT LARCENY   321
# 1  2007-06-03T00:00:00.000   236  DANGEROUS WEAPONS   782
# 2  2010-02-16T00:00:00.000   105            ROBBERY   375
# 3  2009-11-10T00:00:00.000   341      PETIT LARCENY   333
# 4  2006-04-25T00:00:00.000   112        THEFT-FRAUD   739
#
#                           pd_desc crm_atpt_cptd_cd  ...  \
# 0         LARCENY,PETIT FROM AUTO        COMPLETED  ...
# 1        WEAPONS, POSSESSION, ETC        COMPLETED  ...
# 2                ROBBERY,PHARMACY        COMPLETED  ...
# 3  LARCENY,PETIT FROM STORE-SHOPL        COMPLETED  ...
# 4       FRAUD,UNCLASSIFIED-FELONY        COMPLETED  ...
#
#   :@computed_region_sbqj_enih             cmplnt_to_dt cmplnt_to_tm  \
# 0                          46                      NaN          NaN
# 1                          18                      NaN          NaN
# 2                          60  2010-02-16T00:00:00.000     20:50:00
# 3                          51  2009-11-10T00:00:00.000     16:45:00
# 4                         NaN  2006-04-11T00:00:00.000     10:00:00
#
#   loc_of_occur_desc susp_race susp_sex susp_age_group transit_district  \
# 0               NaN       NaN      NaN            NaN              NaN
# 1               NaN       NaN      NaN            NaN              NaN
# 2            INSIDE       NaN      NaN            NaN              NaN
# 3            INSIDE       NaN      NaN            NaN              NaN
# 4               NaN       NaN      NaN            NaN              NaN
#
#   station_name hadevelopt
# 0          NaN        NaN
# 1          NaN        NaN
# 2          NaN        NaN
# 3          NaN        NaN
# 4          NaN        NaN
#
# [5 rows x 40 columns]

# %%
pmap = police.loc[: , ['ofns_desc', 'latitude', 'longitude', 'vic_race', 'susp_race']]

# %%
police.head()
# Out:
#    cmplnt_num             cmplnt_fr_dt cmplnt_fr_tm  addr_pct_cd  \
# 0   876525802  2008-04-10T00:00:00.000     19:10:00         73.0
# 1   402693528  2007-06-03T00:00:00.000     15:23:00         28.0
# 2   832030069  2010-02-16T00:00:00.000     20:50:00        102.0
# 3   538308771  2009-11-10T00:00:00.000     16:35:00         79.0
# 4   965693192  2006-04-11T00:00:00.000     09:30:00        123.0
#
#                     rpt_dt  ky_cd          ofns_desc  pd_cd  \
# 0  2008-04-10T00:00:00.000    341      PETIT LARCENY  321.0
# 1  2007-06-03T00:00:00.000    236  DANGEROUS WEAPONS  782.0
# 2  2010-02-16T00:00:00.000    105            ROBBERY  375.0
# 3  2009-11-10T00:00:00.000    341      PETIT LARCENY  333.0
# 4  2006-04-25T00:00:00.000    112        THEFT-FRAUD  739.0
#
#                           pd_desc crm_atpt_cptd_cd  ...  \
# 0         LARCENY,PETIT FROM AUTO        COMPLETED  ...
# 1        WEAPONS, POSSESSION, ETC        COMPLETED  ...
# 2                ROBBERY,PHARMACY        COMPLETED  ...
# 3  LARCENY,PETIT FROM STORE-SHOPL        COMPLETED  ...
# 4       FRAUD,UNCLASSIFIED-FELONY        COMPLETED  ...
#
#   :@computed_region_sbqj_enih             cmplnt_to_dt cmplnt_to_tm  \
# 0                        46.0                      NaN          NaN
# 1                        18.0                      NaN          NaN
# 2                        60.0  2010-02-16T00:00:00.000     20:50:00
# 3                        51.0  2009-11-10T00:00:00.000     16:45:00
# 4                         NaN  2006-04-11T00:00:00.000     10:00:00
#
#   loc_of_occur_desc  susp_race susp_sex susp_age_group  transit_district  \
# 0               NaN        NaN      NaN            NaN               NaN
# 1               NaN        NaN      NaN            NaN               NaN
# 2            INSIDE        NaN      NaN            NaN               NaN
# 3            INSIDE        NaN      NaN            NaN               NaN
# 4               NaN        NaN      NaN            NaN               NaN
#
#    station_name  hadevelopt
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN
#
# [5 rows x 40 columns]

# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.albanyny.gov", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.albanyny.gov,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("qq93-cnn2", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df.head()
# Out:
#   agency_case_no              report_date time_of_crime occur_begin_day  \
# 0   APD*20044085  2020-04-03T00:00:00.000            15             FRI
# 1   APD*20049362  2020-04-18T00:00:00.000            11             SAT
# 2   APD*19107860  2019-08-05T00:00:00.000             8             FRI
# 3   APD*19175165  2019-12-12T00:00:00.000             0             THU
# 4   APD*19175636  2019-12-12T00:00:00.000            22             THU
#
#           occur_begin_date occur_begin_time occur_end_day  \
# 0  2020-04-03T00:00:00.000            15:35           FRI
# 1  2020-04-18T00:00:00.000            11:30           SAT
# 2  2019-02-01T00:00:00.000            08:00           MON
# 3  2019-12-12T00:00:00.000            00:15           THU
# 4  2019-12-12T00:00:00.000            22:38           THU
#
#             occur_end_date occur_end_time crime_class  \
# 0  2020-04-03T00:00:00.000          15:40          PL
# 1  2020-04-18T00:00:00.000          13:30          PL
# 2  2019-04-01T00:00:00.000          08:00          PL
# 3  2019-12-12T00:00:00.000          00:15          PL
# 4  2019-12-12T00:00:00.000          22:38          PL
#
#                                        incident_type ucr     long_id  \
# 0                       ROB 2 CAUSES PHYSICAL INJURY   3  160102ACF2
# 1                                      PETIT LARCENY   6  1552500AM0
# 2                                      PETIT LARCENY   6  1552500AM0
# 3                         HARASSMENT 2ND-PHY CONTACT  33  24026000V2
# 4  CRIMINAL OBSTRUCTION OF BREATHING OR BLOOD CIR...  24  1211100AM0
#
#   crime_attempt  last_30_days neighborhood_association  \
# 0            No         False          Sheridan Hollow
# 1            No         False                      NaN
# 2            No         False                      NaN
# 3            No         False               Pine Hills
# 4            No         False                South End
#
#                                      neighborhood_xy  \
# 0  {'type': 'Point', 'coordinates': [-73.75740727...
# 1                                                NaN
# 2                                                NaN
# 3  {'type': 'Point', 'coordinates': [-73.78661269...
# 4  {'type': 'Point', 'coordinates': [-73.75926175...
#
#   :@computed_region_84ez_q8p4    class_description
# 0                          26                  NaN
# 1                         NaN  ALL OTHER LARCENIES
# 2                         NaN  THEFT FROM BUILDING
# 3                          22  PERSON DOM VIOLENCE
# 4                          27              UNKNOWN

# %%
arson = pmap.loc[pmap['ofns_desc'] == 'ARSON']

# %%
arson.head()
# Out:
#    ofns_desc   latitude  longitude vic_race susp_race
# 13     ARSON  40.795080 -73.939189  UNKNOWN       NaN
# 35     ARSON  40.682186 -73.839690  UNKNOWN       NaN
# 46     ARSON  40.681655 -73.852488  UNKNOWN       NaN
# 75     ARSON  40.833825 -73.867772  UNKNOWN       NaN
# 81     ARSON  40.576703 -73.994530  UNKNOWN       NaN

# %%
m = folium.Map(location = arson.iloc[0, [1, 2]])
def marker_maker(x):
    folium.CircleMarker(location = [x[1], x[2]], color = 'red', fill = True).add_to(m)

# %%
arson.dropna(subset = ['latitude', 'longitude']).apply(marker_maker, axis = 1)
# Out:
# 13     None
# 35     None
# 46     None
# 75     None
# 81     None
# 113    None
# 158    None
# 168    None
# 279    None
# 289    None
# 320    None
# 353    None
# 363    None
# 372    None
# 376    None
# 444    None
# 518    None
# 587    None
# 588    None
# 688    None
# 704    None
# 710    None
# 730    None
# 774    None
# 825    None
# 890    None
# 898    None
# 913    None
# 945    None
# 947    None
# 962    None
# dtype: object

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
