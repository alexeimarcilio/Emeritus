# %% [markdown]
# # Grouping and Aggregating Data

# %% [markdown]
# ## Outine
# * Splitting data into groups
# * Operations on groupby objects

# %%
import pandas as pd
import numpy as np
from pathlib import Path

df = pd.read_csv(Path('data/employee_attrition.csv'))

# Select only people in this age range
df = df[df.Age >= 21]
df = df[df.Age <= 28]

# %% [markdown]
# ## Splitting data into groups
# This is where every grouping operation begins, by calling the `groupby()` function of a Dataframe object.
#
# Split the data into groups by a single column's value, or multiple.

# %%
grouped = df.groupby('Age')
grouped = df.groupby(['Age', 'Attrition'])

# %% [markdown]
# Iterate over the groups, returning `(groupName, group)`. "groupName" is either the value of the single column of the group, or a tuple containing the values of multiple columns. "group" is a dataframe containing the rows of each group.

# %%
for groupName, group in grouped:
    print(f'{groupName}: {len(group)} rows')
# Out:
# (21, 'No'): 7 rows
# (21, 'Yes'): 6 rows
# (22, 'No'): 11 rows
# (22, 'Yes'): 5 rows
# (23, 'No'): 10 rows
# (23, 'Yes'): 4 rows
# (24, 'No'): 19 rows
# (24, 'Yes'): 7 rows
# (25, 'No'): 20 rows
# (25, 'Yes'): 6 rows
# (26, 'No'): 27 rows
# (26, 'Yes'): 12 rows
# (27, 'No'): 45 rows
# (27, 'Yes'): 3 rows
# (28, 'No'): 34 rows
# (28, 'Yes'): 14 rows

# %% [markdown]
# Select a single group with `get_group()`, passing the value or a tuple of values.

# %%
grouped = df.groupby(['Age', 'Attrition', 'Gender'])

grouped.get_group((24, 'No', 'Female'))
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 20     24        No         Non-Travel        673  Research & Development
# 96     24        No      Travel_Rarely       1353                   Sales
# 380    24        No      Travel_Rarely       1371                   Sales
# 724    24        No      Travel_Rarely       1206  Research & Development
# 1025   24        No      Travel_Rarely       1476                   Sales
# 1061   24        No         Non-Travel        830                   Sales
# 1168   24        No  Travel_Frequently        567  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 20                  11          2             Other              1
# 96                   3          2             Other              1
# 380                 10          4         Marketing              1
# 724                 17          1           Medical              1
# 1025                 4          1           Medical              1
# 1061                13          2     Life Sciences              1
# 1168                 2          1  Technical Degree              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 20                26  ...                         4            80
# 96               128  ...                         1            80
# 380              507  ...                         4            80
# 724             1009  ...                         2            80
# 1025            1445  ...                         3            80
# 1061            1495  ...                         3            80
# 1168            1646  ...                         3            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 20                   1                  5                      5
# 96                   1                  4                      2
# 380                  1                  5                      2
# 724                  2                  5                      6
# 1025                 2                  5                      3
# 1061                 1                  1                      2
# 1168                 0                  6                      2
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 20                 2               4                  2
# 96                 2               3                  2
# 380                4               5                  2
# 724                3               4                  2
# 1025               3               5                  4
# 1061               3               1                  0
# 1168               3               6                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 20                          1                     3
# 96                          0                     2
# 380                         0                     3
# 724                         3                     2
# 1025                        0                     3
# 1061                        0                     0
# 1168                        1                     3
#
# [7 rows x 35 columns]

# %% [markdown]
# ## Operations on groupby objects
#
# After splitting the groups, we usually want to perform some operation on the groups of data returned.
#
# ### Aggregation
#
# Aggregation can be performed by either using the available aggregating functions on the `groupby` object, or using the aggregate function to apply arbtrary function logic.

# %%
grouped = df.groupby('Age')

dfh = grouped['DistanceFromHome'] # pandas SeriesGroupBy object

dfh.mean()
dfh.std()
# Out:
# Age
# 21    6.435080
# 22    7.201562
# 23    6.780710
# 24    8.496244
# 25    8.353719
# 26    9.683033
# 27    6.045924
# 28    8.539333
# Name: DistanceFromHome, dtype: float64

# %%
dfh.aggregate([np.mean, np.std])

dfh.aggregate(lambda x: sum(x) / len(x))
#dfh.mean()
# Out:
# Age
# 21     9.076923
# 22     8.437500
# 23     9.142857
# 24    11.884615
# 25     8.769231
# 26    10.230769
# 27     7.500000
# 28     8.875000
# Name: DistanceFromHome, dtype: float64

# %%
dfh.describe()
# Out:
#      count       mean       std  min   25%   50%    75%   max
# Age
# 21    13.0   9.076923  6.435080  1.0  5.00   9.0  12.00  22.0
# 22    16.0   8.437500  7.201562  1.0  3.00   6.5  12.00  26.0
# 23    14.0   9.142857  6.780710  1.0  4.50   8.5  10.00  26.0
# 24    26.0  11.884615  8.496244  1.0  4.00  10.0  17.75  29.0
# 25    26.0   8.769231  8.353719  1.0  2.25   5.0  12.25  28.0
# 26    39.0  10.230769  9.683033  1.0  2.00   6.0  18.50  29.0
# 27    48.0   7.500000  6.045924  1.0  2.00   6.0  10.00  23.0
# 28    48.0   8.875000  8.539333  1.0  2.00   5.5  15.25  29.0

# %% [markdown]
# You can also transform the data of each group.

# %%
grouped = df.groupby('Age')

# Assign every value of DailyRate within each age group to the mean of the group
standardized_rates = grouped['DailyRate'].transform(np.mean)

df.assign(DailyRate=standardized_rates)
# Out:
#       Age Attrition     BusinessTravel   DailyRate              Department  \
# 4      27        No      Travel_Rarely  907.333333  Research & Development
# 14     28       Yes      Travel_Rarely  927.500000  Research & Development
# 17     22        No         Non-Travel  806.937500  Research & Development
# 20     24        No         Non-Travel  863.115385  Research & Development
# 23     21        No      Travel_Rarely  762.846154  Research & Development
# ...   ...       ...                ...         ...                     ...
# 1433   25        No      Travel_Rarely  768.076923                   Sales
# 1436   21        No      Travel_Rarely  762.846154                   Sales
# 1438   23       Yes  Travel_Frequently  707.928571                   Sales
# 1464   26        No      Travel_Rarely  844.769231                   Sales
# 1467   27        No      Travel_Rarely  907.333333  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 4                    2          1        Medical              1
# 14                  24          3  Life Sciences              1
# 17                  16          2        Medical              1
# 20                  11          2          Other              1
# 23                  15          2  Life Sciences              1
# ...                ...        ...            ...            ...
# 1433                 8          2          Other              1
# 1436                 5          1        Medical              1
# 1438                 9          3      Marketing              1
# 1464                 5          3          Other              1
# 1467                 4          3  Life Sciences              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 4                  7  ...                         4            80
# 14                19  ...                         2            80
# 17                22  ...                         2            80
# 20                26  ...                         4            80
# 23                30  ...                         4            80
# ...              ...  ...                       ...           ...
# 1433            2018  ...                         2            80
# 1436            2021  ...                         4            80
# 1438            2023  ...                         1            80
# 1464            2060  ...                         4            80
# 1467            2064  ...                         2            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 4                    1                  6                      3
# 14                   0                  6                      4
# 17                   2                  1                      2
# 20                   1                  5                      5
# 23                   0                  0                      6
# ...                ...                ...                    ...
# 1433                 1                  6                      3
# 1436                 0                  2                      6
# 1438                 1                  1                      3
# 1464                 0                  5                      2
# 1467                 1                  6                      0
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 4                  3               2                  2
# 14                 3               4                  2
# 17                 2               1                  0
# 20                 2               4                  2
# 23                 3               0                  0
# ...              ...             ...                ...
# 1433               2               5                  3
# 1436               3               2                  2
# 1438               2               1                  0
# 1464               3               4                  2
# 1467               3               6                  2
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 4                           2                     2
# 14                          0                     3
# 17                          0                     0
# 20                          1                     3
# 23                          0                     0
# ...                       ...                   ...
# 1433                        0                     4
# 1436                        1                     2
# 1438                        1                     0
# 1464                        0                     0
# 1467                        0                     3
#
# [230 rows x 35 columns]

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 4      27        No      Travel_Rarely        591  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 17     22        No         Non-Travel       1123  Research & Development
# 20     24        No         Non-Travel        673  Research & Development
# 23     21        No      Travel_Rarely        391  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1433   25        No      Travel_Rarely       1382                   Sales
# 1436   21        No      Travel_Rarely        501                   Sales
# 1438   23       Yes  Travel_Frequently        638                   Sales
# 1464   26        No      Travel_Rarely       1167                   Sales
# 1467   27        No      Travel_Rarely        155  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 4                    2          1        Medical              1
# 14                  24          3  Life Sciences              1
# 17                  16          2        Medical              1
# 20                  11          2          Other              1
# 23                  15          2  Life Sciences              1
# ...                ...        ...            ...            ...
# 1433                 8          2          Other              1
# 1436                 5          1        Medical              1
# 1438                 9          3      Marketing              1
# 1464                 5          3          Other              1
# 1467                 4          3  Life Sciences              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 4                  7  ...                         4            80
# 14                19  ...                         2            80
# 17                22  ...                         2            80
# 20                26  ...                         4            80
# 23                30  ...                         4            80
# ...              ...  ...                       ...           ...
# 1433            2018  ...                         2            80
# 1436            2021  ...                         4            80
# 1438            2023  ...                         1            80
# 1464            2060  ...                         4            80
# 1467            2064  ...                         2            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 4                    1                  6                      3
# 14                   0                  6                      4
# 17                   2                  1                      2
# 20                   1                  5                      5
# 23                   0                  0                      6
# ...                ...                ...                    ...
# 1433                 1                  6                      3
# 1436                 0                  2                      6
# 1438                 1                  1                      3
# 1464                 0                  5                      2
# 1467                 1                  6                      0
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 4                  3               2                  2
# 14                 3               4                  2
# 17                 2               1                  0
# 20                 2               4                  2
# 23                 3               0                  0
# ...              ...             ...                ...
# 1433               2               5                  3
# 1436               3               2                  2
# 1438               2               1                  0
# 1464               3               4                  2
# 1467               3               6                  2
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 4                           2                     2
# 14                          0                     3
# 17                          0                     0
# 20                          1                     3
# 23                          0                     0
# ...                       ...                   ...
# 1433                        0                     4
# 1436                        1                     2
# 1438                        1                     0
# 1464                        0                     0
# 1467                        0                     3
#
# [230 rows x 35 columns]

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 4      27        No      Travel_Rarely        591  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 17     22        No         Non-Travel       1123  Research & Development
# 20     24        No         Non-Travel        673  Research & Development
# 23     21        No      Travel_Rarely        391  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1433   25        No      Travel_Rarely       1382                   Sales
# 1436   21        No      Travel_Rarely        501                   Sales
# 1438   23       Yes  Travel_Frequently        638                   Sales
# 1464   26        No      Travel_Rarely       1167                   Sales
# 1467   27        No      Travel_Rarely        155  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 4                    2          1        Medical              1
# 14                  24          3  Life Sciences              1
# 17                  16          2        Medical              1
# 20                  11          2          Other              1
# 23                  15          2  Life Sciences              1
# ...                ...        ...            ...            ...
# 1433                 8          2          Other              1
# 1436                 5          1        Medical              1
# 1438                 9          3      Marketing              1
# 1464                 5          3          Other              1
# 1467                 4          3  Life Sciences              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 4                  7  ...                         4            80
# 14                19  ...                         2            80
# 17                22  ...                         2            80
# 20                26  ...                         4            80
# 23                30  ...                         4            80
# ...              ...  ...                       ...           ...
# 1433            2018  ...                         2            80
# 1436            2021  ...                         4            80
# 1438            2023  ...                         1            80
# 1464            2060  ...                         4            80
# 1467            2064  ...                         2            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 4                    1                  6                      3
# 14                   0                  6                      4
# 17                   2                  1                      2
# 20                   1                  5                      5
# 23                   0                  0                      6
# ...                ...                ...                    ...
# 1433                 1                  6                      3
# 1436                 0                  2                      6
# 1438                 1                  1                      3
# 1464                 0                  5                      2
# 1467                 1                  6                      0
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 4                  3               2                  2
# 14                 3               4                  2
# 17                 2               1                  0
# 20                 2               4                  2
# 23                 3               0                  0
# ...              ...             ...                ...
# 1433               2               5                  3
# 1436               3               2                  2
# 1438               2               1                  0
# 1464               3               4                  2
# 1467               3               6                  2
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 4                           2                     2
# 14                          0                     3
# 17                          0                     0
# 20                          1                     3
# 23                          0                     0
# ...                       ...                   ...
# 1433                        0                     4
# 1436                        1                     2
# 1438                        1                     0
# 1464                        0                     0
# 1467                        0                     3
#
# [230 rows x 35 columns]
