# %% [markdown]
# # Grouping and Aggregating Data

# %% [markdown]
# ## Outine
# * Splitting data into groups
# * Operations on groupby objects

# %%
import pandas as pd
import numpy as np
from pathlib import Path

df = pd.read_csv(Path('data/employee_attrition.csv'))

# Select only people in this age range
df = df[df.Age >= 21]
df = df[df.Age <= 28]

# %% [markdown]
# ## Splitting data into groups
# This is where every grouping operation begins, by calling the `groupby()` function of a Dataframe object.
#
# Split the data into groups by a single column's value, or multiple.

# %%
grouped = df.groupby('Age')
grouped = df.groupby(['Age', 'Attrition'])

# %% [markdown]
# Iterate over the groups, returning `(groupName, group)`. "groupName" is either the value of the single column of the group, or a tuple containing the values of multiple columns. "group" is a dataframe containing the rows of each group.

# %%
for groupName, group in grouped:
    print(f'{groupName}: {len(group)} rows')
# Out:
# (21, 'No'): 7 rows
# (21, 'Yes'): 6 rows
# (22, 'No'): 11 rows
# (22, 'Yes'): 5 rows
# (23, 'No'): 10 rows
# (23, 'Yes'): 4 rows
# (24, 'No'): 19 rows
# (24, 'Yes'): 7 rows
# (25, 'No'): 20 rows
# (25, 'Yes'): 6 rows
# (26, 'No'): 27 rows
# (26, 'Yes'): 12 rows
# (27, 'No'): 45 rows
# (27, 'Yes'): 3 rows
# (28, 'No'): 34 rows
# (28, 'Yes'): 14 rows

# %% [markdown]
# Select a single group with `get_group()`, passing the value or a tuple of values.

# %%
grouped = df.groupby(['Age', 'Attrition', 'Gender'])

grouped.get_group((24, 'No', 'Female'))
# Out:
#       Age Attrition     BusinessTravel  DailyRate  DistanceFromHome  \
# 20     24        No         Non-Travel        673                11
# 96     24        No      Travel_Rarely       1353                 3
# 380    24        No      Travel_Rarely       1371                10
# 724    24        No      Travel_Rarely       1206                17
# 1025   24        No      Travel_Rarely       1476                 4
# 1061   24        No         Non-Travel        830                13
# 1168   24        No  Travel_Frequently        567                 2
#
#       EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 20                          1  Female          96               4         2
# 96                          1  Female          33               3         2
# 380                         4  Female          77               3         2
# 724                         4  Female          41               2         2
# 1025                        4  Female          42               3         2
# 1061                        4  Female          78               3         1
# 1168                        1  Female          32               3         1
#
#       ...  PerformanceRating RelationshipSatisfaction  StockOptionLevel  \
# 20    ...                  3                        4                 1
# 96    ...                  4                        1                 1
# 380   ...                  3                        4                 1
# 724   ...                  3                        2                 2
# 1025  ...                  3                        3                 2
# 1061  ...                  3                        3                 1
# 1168  ...                  3                        3                 0
#
#       TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# 20                    5                     5                2
# 96                    4                     2                2
# 380                   5                     2                4
# 724                   5                     6                3
# 1025                  5                     3                3
# 1061                  1                     2                3
# 1168                  6                     2                3
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 20                 4                   2                        1
# 96                 3                   2                        0
# 380                5                   2                        0
# 724                4                   2                        3
# 1025               5                   4                        0
# 1061               1                   0                        0
# 1168               6                   3                        1
#
#       YearsWithCurrManager
# 20                       3
# 96                       2
# 380                      3
# 724                      2
# 1025                     3
# 1061                     0
# 1168                     3
#
# [7 rows x 26 columns]

# %% [markdown]
# ## Operations on groupby objects
#
# After splitting the groups, we usually want to perform some operation on the groups of data returned.
#
# ### Aggregation
#
# Aggregation can be performed by either using the available aggregating functions on the `groupby` object, or using the aggregate function to apply arbtrary function logic.

# %%
grouped = df.groupby('Age')

dfh = grouped['DistanceFromHome'] # pandas SeriesGroupBy object

dfh.mean()
dfh.std()
# Out:
# Age
# 21    6.435080
# 22    7.201562
# 23    6.780710
# 24    8.496244
# 25    8.353719
# 26    9.683033
# 27    6.045924
# 28    8.539333
# Name: DistanceFromHome, dtype: float64

# %%
dfh.aggregate([np.mean, np.std])

dfh.aggregate(lambda x: sum(x) / len(x))
#dfh.mean()
# Out:
# Age
# 21     9.076923
# 22     8.437500
# 23     9.142857
# 24    11.884615
# 25     8.769231
# 26    10.230769
# 27     7.500000
# 28     8.875000
# Name: DistanceFromHome, dtype: float64

# %% [markdown]
# You can also transform the data of each group.

# %%
grouped = df.groupby('Age')

# Assign every value of DailyRate within each age group to the mean of the group
standardized_rates = grouped['DailyRate'].transform(np.mean)

df.assign(DailyRate=standardized_rates)
# Out:
#       Age Attrition     BusinessTravel   DailyRate  DistanceFromHome  \
# 4      27        No      Travel_Rarely  907.333333                 2
# 14     28       Yes      Travel_Rarely  927.500000                24
# 17     22        No         Non-Travel  806.937500                16
# 20     24        No         Non-Travel  863.115385                11
# 23     21        No      Travel_Rarely  762.846154                15
# ...   ...       ...                ...         ...               ...
# 1433   25        No      Travel_Rarely  768.076923                 8
# 1436   21        No      Travel_Rarely  762.846154                 5
# 1438   23       Yes  Travel_Frequently  707.928571                 9
# 1464   26        No      Travel_Rarely  844.769231                 5
# 1467   27        No      Travel_Rarely  907.333333                 4
#
#       EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 4                           1    Male          40               3         1
# 14                          3    Male          50               2         1
# 17                          4    Male          96               4         1
# 20                          1  Female          96               4         2
# 23                          3    Male          96               3         1
# ...                       ...     ...         ...             ...       ...
# 1433                        1  Female          85               3         2
# 1436                        3    Male          58               3         1
# 1438                        4    Male          33               3         1
# 1464                        4  Female          30               2         1
# 1467                        2    Male          87               4         2
#
#       ...  PerformanceRating RelationshipSatisfaction  StockOptionLevel  \
# 4     ...                  3                        4                 1
# 14    ...                  3                        2                 0
# 17    ...                  3                        2                 2
# 20    ...                  3                        4                 1
# 23    ...                  3                        4                 0
# ...   ...                ...                      ...               ...
# 1433  ...                  4                        2                 1
# 1436  ...                  3                        4                 0
# 1438  ...                  3                        1                 1
# 1464  ...                  3                        4                 0
# 1467  ...                  4                        2                 1
#
#       TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# 4                     6                     3                3
# 14                    6                     4                3
# 17                    1                     2                2
# 20                    5                     5                2
# 23                    0                     6                3
# ...                 ...                   ...              ...
# 1433                  6                     3                2
# 1436                  2                     6                3
# 1438                  1                     3                2
# 1464                  5                     2                3
# 1467                  6                     0                3
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 4                  2                   2                        2
# 14                 4                   2                        0
# 17                 1                   0                        0
# 20                 4                   2                        1
# 23                 0                   0                        0
# ...              ...                 ...                      ...
# 1433               5                   3                        0
# 1436               2                   2                        1
# 1438               1                   0                        1
# 1464               4                   2                        0
# 1467               6                   2                        0
#
#       YearsWithCurrManager
# 4                        2
# 14                       3
# 17                       0
# 20                       3
# 23                       0
# ...                    ...
# 1433                     4
# 1436                     2
# 1438                     0
# 1464                     0
# 1467                     3
#
# [230 rows x 26 columns]
