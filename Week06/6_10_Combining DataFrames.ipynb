# %% [markdown]
# # Combining DataFrames

# %% [markdown]
# ## Outline
# * Why combine DataFrames?
# * Working with HR Data
# * `pd.concat([...])`
# * Working with Survey Data
# * `DataFrame.append(other)`
# * Correlating rows with `DataFrame.merge(other)`
#
# ## Why combine DataFrames?
# It is often useful to combine more than one DataFrame together in different ways to create a larger DataFrame.  To illustrate this, we have a task:  Our goal is to collect information about our employees, and correlate it with survey data. The data happens to come from different sources, and we will have to combine them correctly.

# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# ## Working with HR Data
# Our HR department has provided the data we need, but it's split into two separate files, `hr_core.csv` for core employee identification data, and `hr.csv` for the additional data. Both files have a unique column of `e_id`, which is the employee's ID number.  Both files have the same number of records, in the same order, and corresponding to the same set of employees.

# %%
hr_data_core = pd.read_csv(Path('data/combining/hr_core.csv'))
hr_data = pd.read_csv(Path('data/combining/hr.csv'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-66ab67460d81> in <module>
# ----> 1 hr_data_core = pd.read_csv(Path('data/combining/hr_core.csv'))
#       2 hr_data = pd.read_csv(Path('data/combining/hr.csv'))
#
# ~/ds/eme/pro/my_project_env/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/ds/eme/pro/my_project_env/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/ds/eme/pro/my_project_env/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/ds/eme/pro/my_project_env/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/ds/eme/pro/my_project_env/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File data/combining/hr_core.csv does not exist: 'data/combining/hr_core.csv'

# %%
hr_data_core
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d3fbf59e9221> in <module>
# ----> 1 hr_data_core
#
# NameError: name 'hr_data_core' is not defined

# %%
hr_data
# Out:
#          e_id Attrition  DailyRate  HourlyRate  PerformanceRating  \
# 0     6368264       Yes       1102          94                  3
# 1     6589733        No        279          61                  4
# 2     6921082       Yes       1373          92                  3
# 3     8516310        No       1392          56                  3
# 4     2305936        No        591          40                  3
# ...       ...       ...        ...         ...                ...
# 1465  7536967        No        884          41                  3
# 1466  9736015        No        613          42                  3
# 1467  5747226        No        155          87                  4
# 1468  1586705        No       1023          63                  3
# 1469  7529820        No        628          82                  3
#
#       StockOptionLevel
# 0                    0
# 1                    1
# 2                    0
# 3                    0
# 4                    1
# ...                ...
# 1465                 1
# 1466                 1
# 1467                 1
# 1468                 0
# 1469                 0
#
# [1470 rows x 6 columns]

# %% [markdown]
# ## `pd.concat([...])`
#
# Let's combine these two DataFrames by concatenating the columns of both into one DataFrame. We do this with `pd.concat()`, which accepts a list-like collection of dataframes.  Specify `axis='columns'` to concatenate along the columns axis.

# %%
hr_data_all = pd.concat([hr_data_core, hr_data], axis='columns')
hr_data_all # notice we have two 'e_id' columns in the result
# Out:
#          e_id  Age  Gender     e_id Attrition  DailyRate  HourlyRate  \
# 0     6368264   41  Female  6368264       Yes       1102          94
# 1     6589733   49    Male  6589733        No        279          61
# 2     6921082   37    Male  6921082       Yes       1373          92
# 3     8516310   33  Female  8516310        No       1392          56
# 4     2305936   27    Male  2305936        No        591          40
# ...       ...  ...     ...      ...       ...        ...         ...
# 1465  7536967   36    Male  7536967        No        884          41
# 1466  9736015   39    Male  9736015        No        613          42
# 1467  5747226   27    Male  5747226        No        155          87
# 1468  1586705   49    Male  1586705        No       1023          63
# 1469  7529820   34    Male  7529820        No        628          82
#
#       PerformanceRating  StockOptionLevel
# 0                     3                 0
# 1                     4                 1
# 2                     3                 0
# 3                     3                 0
# 4                     3                 1
# ...                 ...               ...
# 1465                  3                 1
# 1466                  3                 1
# 1467                  4                 1
# 1468                  3                 0
# 1469                  3                 0
#
# [1470 rows x 9 columns]

# %% [markdown]
# Let's remove the `e_id` column from the second DataFrame before concatenating to clean up our results:

# %%
hr_data_all = pd.concat([hr_data_core, hr_data.drop(columns='e_id')], axis='columns')
hr_data_all
# Out:
#          e_id  Age  Gender Attrition  DailyRate  HourlyRate  \
# 0     6368264   41  Female       Yes       1102          94
# 1     6589733   49    Male        No        279          61
# 2     6921082   37    Male       Yes       1373          92
# 3     8516310   33  Female        No       1392          56
# 4     2305936   27    Male        No        591          40
# ...       ...  ...     ...       ...        ...         ...
# 1465  7536967   36    Male        No        884          41
# 1466  9736015   39    Male        No        613          42
# 1467  5747226   27    Male        No        155          87
# 1468  1586705   49    Male        No       1023          63
# 1469  7529820   34    Male        No        628          82
#
#       PerformanceRating  StockOptionLevel
# 0                     3                 0
# 1                     4                 1
# 2                     3                 0
# 3                     3                 0
# 4                     3                 1
# ...                 ...               ...
# 1465                  3                 1
# 1466                  3                 1
# 1467                  4                 1
# 1468                  3                 0
# 1469                  3                 0
#
# [1470 rows x 8 columns]

# %% [markdown]
# ## Working with Survey Data
#
# We have two survey teams, and they've both provided their results in a separate file (`survey1.csv` and `survey2.csv`). The both have the same columns, and have a column called `employee_id` for the employees ID number.

# %%
survey_1 = pd.read_csv(Path('data/combining/survey1.csv'))
survey_2 = pd.read_csv(Path('data/combining/survey2.csv'))

# %%
survey_1
# Out:
#      employee_id     BusinessTravel  DistanceFromHome  JobInvolvement  \
# 0        1916998      Travel_Rarely                 9               3
# 1        6107122      Travel_Rarely                 2               3
# 2        9945477      Travel_Rarely                22               4
# 3        9078723      Travel_Rarely                15               3
# 4        3459571      Travel_Rarely                28               2
# ..           ...                ...               ...             ...
# 524      5276056      Travel_Rarely                 4               3
# 525      1250631  Travel_Frequently                 6               4
# 526       553990      Travel_Rarely                13               3
# 527      3023099      Travel_Rarely                 8               2
# 528      4367366  Travel_Frequently                 1               3
#
#      EnvironmentSatisfaction  RelationshipSatisfaction
# 0                          4                         4
# 1                          3                         3
# 2                          2                         2
# 3                          2                         3
# 4                          4                         2
# ..                       ...                       ...
# 524                        1                         2
# 525                        1                         4
# 526                        2                         3
# 527                        1                         3
# 528                        3                         1
#
# [529 rows x 6 columns]

# %%
survey_2
# Out:
#      employee_id     BusinessTravel  DistanceFromHome  JobInvolvement  \
# 0        5395078      Travel_Rarely                25               2
# 1        9351597  Travel_Frequently                 2               3
# 2        2588608      Travel_Rarely                 1               3
# 3        6987632      Travel_Rarely                20               3
# 4        4870009      Travel_Rarely                 5               3
# ..           ...                ...               ...             ...
# 617      9875709      Travel_Rarely                 2               3
# 618      6973299      Travel_Rarely                 8               3
# 619      5821045  Travel_Frequently                 2               3
# 620      7609085      Travel_Rarely                 3               3
# 621      5851213      Travel_Rarely                 1               2
#
#      EnvironmentSatisfaction  RelationshipSatisfaction
# 0                          2                         4
# 1                          2                         4
# 2                          4                         4
# 3                          1                         4
# 4                          3                         4
# ..                       ...                       ...
# 617                        4                         2
# 618                        1                         1
# 619                        4                         3
# 620                        4                         2
# 621                        2                         4
#
# [622 rows x 6 columns]

# %% [markdown]
# ## `DataFrame.append(other)`
#
# Easily combine rows from another DataFrame of the same shape using `append`

# %%
survey_data = survey_1.append(survey_2)
survey_data
# Out:
#      employee_id     BusinessTravel  DistanceFromHome  JobInvolvement  \
# 0        1916998      Travel_Rarely                 9               3
# 1        6107122      Travel_Rarely                 2               3
# 2        9945477      Travel_Rarely                22               4
# 3        9078723      Travel_Rarely                15               3
# 4        3459571      Travel_Rarely                28               2
# ..           ...                ...               ...             ...
# 617      9875709      Travel_Rarely                 2               3
# 618      6973299      Travel_Rarely                 8               3
# 619      5821045  Travel_Frequently                 2               3
# 620      7609085      Travel_Rarely                 3               3
# 621      5851213      Travel_Rarely                 1               2
#
#      EnvironmentSatisfaction  RelationshipSatisfaction
# 0                          4                         4
# 1                          3                         3
# 2                          2                         2
# 3                          2                         3
# 4                          4                         2
# ..                       ...                       ...
# 617                        4                         2
# 618                        1                         1
# 619                        4                         3
# 620                        4                         2
# 621                        2                         4
#
# [1151 rows x 6 columns]

# %% [markdown]
# Notice the row index doesn't seem right.  This is because the row index values are kept from the original dataframes.  Use `reset_index(drop=True)` to reset it to the default values.

# %%
survey_data = survey_data.reset_index(drop=True)
survey_data
# Out:
#       employee_id     BusinessTravel  DistanceFromHome  JobInvolvement  \
# 0         1916998      Travel_Rarely                 9               3
# 1         6107122      Travel_Rarely                 2               3
# 2         9945477      Travel_Rarely                22               4
# 3         9078723      Travel_Rarely                15               3
# 4         3459571      Travel_Rarely                28               2
# ...           ...                ...               ...             ...
# 1146      9875709      Travel_Rarely                 2               3
# 1147      6973299      Travel_Rarely                 8               3
# 1148      5821045  Travel_Frequently                 2               3
# 1149      7609085      Travel_Rarely                 3               3
# 1150      5851213      Travel_Rarely                 1               2
#
#       EnvironmentSatisfaction  RelationshipSatisfaction
# 0                           4                         4
# 1                           3                         3
# 2                           2                         2
# 3                           2                         3
# 4                           4                         2
# ...                       ...                       ...
# 1146                        4                         2
# 1147                        1                         1
# 1148                        4                         3
# 1149                        4                         2
# 1150                        2                         4
#
# [1151 rows x 6 columns]

# %% [markdown]
# ## Correlating rows with `DataFrame.merge(other)`
#
# So now we have data from HR, and data from our survey.  We need to match all of the rows from those tables that we can. This is precisely the purpose of the `merge()` function.  If you're familiar with the concept of a `JOIN` in SQL, this is analagous.

# %%
merged = hr_data_all.merge(
    survey_data, # the dataframe we're merging with
    left_on='e_id', # match rows from hr_data using column 'e_id'
    right_on='employee_id', # match rows from survey_data using column 'employee_id'
    how='left' # include all rows from hr_data, regardless of whether a match exists in survey_data
)

merged
# Out:
#          e_id  Age  Gender Attrition  DailyRate  HourlyRate  \
# 0     6368264   41  Female       Yes       1102          94
# 1     6589733   49    Male        No        279          61
# 2     6921082   37    Male       Yes       1373          92
# 3     8516310   33  Female        No       1392          56
# 4     2305936   27    Male        No        591          40
# ...       ...  ...     ...       ...        ...         ...
# 1465  7536967   36    Male        No        884          41
# 1466  9736015   39    Male        No        613          42
# 1467  5747226   27    Male        No        155          87
# 1468  1586705   49    Male        No       1023          63
# 1469  7529820   34    Male        No        628          82
#
#       PerformanceRating  StockOptionLevel  employee_id     BusinessTravel  \
# 0                     3                 0    6368264.0      Travel_Rarely
# 1                     4                 1    6589733.0  Travel_Frequently
# 2                     3                 0    6921082.0      Travel_Rarely
# 3                     3                 0    8516310.0  Travel_Frequently
# 4                     3                 1    2305936.0      Travel_Rarely
# ...                 ...               ...          ...                ...
# 1465                  3                 1    7536967.0  Travel_Frequently
# 1466                  3                 1    9736015.0      Travel_Rarely
# 1467                  4                 1    5747226.0      Travel_Rarely
# 1468                  3                 0    1586705.0  Travel_Frequently
# 1469                  3                 0    7529820.0      Travel_Rarely
#
#       DistanceFromHome  JobInvolvement  EnvironmentSatisfaction  \
# 0                  1.0             3.0                      2.0
# 1                  8.0             2.0                      3.0
# 2                  2.0             2.0                      4.0
# 3                  3.0             3.0                      4.0
# 4                  2.0             3.0                      1.0
# ...                ...             ...                      ...
# 1465              23.0             4.0                      3.0
# 1466               6.0             2.0                      4.0
# 1467               4.0             4.0                      2.0
# 1468               2.0             2.0                      4.0
# 1469               8.0             4.0                      2.0
#
#       RelationshipSatisfaction
# 0                          1.0
# 1                          4.0
# 2                          2.0
# 3                          3.0
# 4                          4.0
# ...                        ...
# 1465                       3.0
# 1466                       1.0
# 1467                       2.0
# 1468                       4.0
# 1469                       1.0
#
# [1470 rows x 14 columns]

# %% [markdown]
# However, there were more rows in `hr_data_all` than in `survey_data`.  This means we must have rows with missing survey data.

# %%
empty_rows = merged.loc[merged.employee_id.isnull()]
empty_rows
# Out:
#          e_id  Age  Gender Attrition  DailyRate  HourlyRate  \
# 7     9971859   30    Male        No       1358          67
# 8     2020122   38    Male        No        216          44
# 9      662896   36    Male        No       1299          94
# 11    7964483   29  Female        No        153          49
# 33    2358008   39    Male       Yes        895          56
# ...       ...  ...     ...       ...        ...         ...
# 1432  4683498   37  Female        No        161          42
# 1438   134901   23    Male       Yes        638          33
# 1442  9579763   29    Male       Yes       1092          36
# 1455  8362686   40    Male        No       1322          52
# 1462   956611   39  Female        No        722          60
#
#       PerformanceRating  StockOptionLevel  employee_id BusinessTravel  \
# 7                     4                 1          NaN            NaN
# 8                     4                 0          NaN            NaN
# 9                     3                 2          NaN            NaN
# 11                    3                 0          NaN            NaN
# 33                    3                 1          NaN            NaN
# ...                 ...               ...          ...            ...
# 1432                  4                 1          NaN            NaN
# 1438                  3                 1          NaN            NaN
# 1442                  3                 3          NaN            NaN
# 1455                  3                 0          NaN            NaN
# 1462                  3                 1          NaN            NaN
#
#       DistanceFromHome  JobInvolvement  EnvironmentSatisfaction  \
# 7                  NaN             NaN                      NaN
# 8                  NaN             NaN                      NaN
# 9                  NaN             NaN                      NaN
# 11                 NaN             NaN                      NaN
# 33                 NaN             NaN                      NaN
# ...                ...             ...                      ...
# 1432               NaN             NaN                      NaN
# 1438               NaN             NaN                      NaN
# 1442               NaN             NaN                      NaN
# 1455               NaN             NaN                      NaN
# 1462               NaN             NaN                      NaN
#
#       RelationshipSatisfaction
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 11                         NaN
# 33                         NaN
# ...                        ...
# 1432                       NaN
# 1438                       NaN
# 1442                       NaN
# 1455                       NaN
# 1462                       NaN
#
# [319 rows x 14 columns]

# %% [markdown]
# We can get rid of them with a combination of `loc[]` and `Series.notnull()`

# %%
merged_noempty = merged.loc[merged.employee_id.notnull()]
merged_noempty
# Out:
#          e_id  Age  Gender Attrition  DailyRate  HourlyRate  \
# 0     6368264   41  Female       Yes       1102          94
# 1     6589733   49    Male        No        279          61
# 2     6921082   37    Male       Yes       1373          92
# 3     8516310   33  Female        No       1392          56
# 4     2305936   27    Male        No        591          40
# ...       ...  ...     ...       ...        ...         ...
# 1465  7536967   36    Male        No        884          41
# 1466  9736015   39    Male        No        613          42
# 1467  5747226   27    Male        No        155          87
# 1468  1586705   49    Male        No       1023          63
# 1469  7529820   34    Male        No        628          82
#
#       PerformanceRating  StockOptionLevel  employee_id     BusinessTravel  \
# 0                     3                 0    6368264.0      Travel_Rarely
# 1                     4                 1    6589733.0  Travel_Frequently
# 2                     3                 0    6921082.0      Travel_Rarely
# 3                     3                 0    8516310.0  Travel_Frequently
# 4                     3                 1    2305936.0      Travel_Rarely
# ...                 ...               ...          ...                ...
# 1465                  3                 1    7536967.0  Travel_Frequently
# 1466                  3                 1    9736015.0      Travel_Rarely
# 1467                  4                 1    5747226.0      Travel_Rarely
# 1468                  3                 0    1586705.0  Travel_Frequently
# 1469                  3                 0    7529820.0      Travel_Rarely
#
#       DistanceFromHome  JobInvolvement  EnvironmentSatisfaction  \
# 0                  1.0             3.0                      2.0
# 1                  8.0             2.0                      3.0
# 2                  2.0             2.0                      4.0
# 3                  3.0             3.0                      4.0
# 4                  2.0             3.0                      1.0
# ...                ...             ...                      ...
# 1465              23.0             4.0                      3.0
# 1466               6.0             2.0                      4.0
# 1467               4.0             4.0                      2.0
# 1468               2.0             2.0                      4.0
# 1469               8.0             4.0                      2.0
#
#       RelationshipSatisfaction
# 0                          1.0
# 1                          4.0
# 2                          2.0
# 3                          3.0
# 4                          4.0
# ...                        ...
# 1465                       3.0
# 1466                       1.0
# 1467                       2.0
# 1468                       4.0
# 1469                       1.0
#
# [1151 rows x 14 columns]

# %% [markdown]
# However, we can also perform an "inner" merge, which will ensure that all of our rows have both HR Data and Survey Data:

# %%
merged = hr_data_all.merge(survey_data, left_on='e_id', right_on='employee_id', how='inner')
merged = hr_data_all.merge(survey_data, left_on='e_id', right_on='employee_id') # inner is the default

merged
# Out:
#          e_id  Age  Gender Attrition  DailyRate  HourlyRate  \
# 0     6368264   41  Female       Yes       1102          94
# 1     6589733   49    Male        No        279          61
# 2     6921082   37    Male       Yes       1373          92
# 3     8516310   33  Female        No       1392          56
# 4     2305936   27    Male        No        591          40
# ...       ...  ...     ...       ...        ...         ...
# 1146  7536967   36    Male        No        884          41
# 1147  9736015   39    Male        No        613          42
# 1148  5747226   27    Male        No        155          87
# 1149  1586705   49    Male        No       1023          63
# 1150  7529820   34    Male        No        628          82
#
#       PerformanceRating  StockOptionLevel  employee_id     BusinessTravel  \
# 0                     3                 0      6368264      Travel_Rarely
# 1                     4                 1      6589733  Travel_Frequently
# 2                     3                 0      6921082      Travel_Rarely
# 3                     3                 0      8516310  Travel_Frequently
# 4                     3                 1      2305936      Travel_Rarely
# ...                 ...               ...          ...                ...
# 1146                  3                 1      7536967  Travel_Frequently
# 1147                  3                 1      9736015      Travel_Rarely
# 1148                  4                 1      5747226      Travel_Rarely
# 1149                  3                 0      1586705  Travel_Frequently
# 1150                  3                 0      7529820      Travel_Rarely
#
#       DistanceFromHome  JobInvolvement  EnvironmentSatisfaction  \
# 0                    1               3                        2
# 1                    8               2                        3
# 2                    2               2                        4
# 3                    3               3                        4
# 4                    2               3                        1
# ...                ...             ...                      ...
# 1146                23               4                        3
# 1147                 6               2                        4
# 1148                 4               4                        2
# 1149                 2               2                        4
# 1150                 8               4                        2
#
#       RelationshipSatisfaction
# 0                            1
# 1                            4
# 2                            2
# 3                            3
# 4                            4
# ...                        ...
# 1146                         3
# 1147                         1
# 1148                         2
# 1149                         4
# 1150                         1
#
# [1151 rows x 14 columns]

# %% [markdown]
# To show how this might look in the wild, here's a snippet of code that produces the final result from the beginning

# %%
hr_data_core = pd.read_csv(Path('data/combining/hr_core.csv'))
hr_data = pd.read_csv(Path('data/combining/hr.csv'))
survey_1 = pd.read_csv(Path('data/combining/survey1.csv'))
survey_2 = pd.read_csv(Path('data/combining/survey2.csv'))

final = pd.concat([hr_data_core, hr_data.drop(columns='e_id')], axis='columns') \
    .merge(survey_1.append(survey_2), left_on='e_id', right_on='employee_id') \
    .drop(columns='employee_id') # drop the now duplicated 'employee_id' col!

final
# Out:
#          e_id  Age  Gender Attrition  DailyRate  HourlyRate  \
# 0     6368264   41  Female       Yes       1102          94
# 1     6589733   49    Male        No        279          61
# 2     6921082   37    Male       Yes       1373          92
# 3     8516310   33  Female        No       1392          56
# 4     2305936   27    Male        No        591          40
# ...       ...  ...     ...       ...        ...         ...
# 1146  7536967   36    Male        No        884          41
# 1147  9736015   39    Male        No        613          42
# 1148  5747226   27    Male        No        155          87
# 1149  1586705   49    Male        No       1023          63
# 1150  7529820   34    Male        No        628          82
#
#       PerformanceRating  StockOptionLevel     BusinessTravel  \
# 0                     3                 0      Travel_Rarely
# 1                     4                 1  Travel_Frequently
# 2                     3                 0      Travel_Rarely
# 3                     3                 0  Travel_Frequently
# 4                     3                 1      Travel_Rarely
# ...                 ...               ...                ...
# 1146                  3                 1  Travel_Frequently
# 1147                  3                 1      Travel_Rarely
# 1148                  4                 1      Travel_Rarely
# 1149                  3                 0  Travel_Frequently
# 1150                  3                 0      Travel_Rarely
#
#       DistanceFromHome  JobInvolvement  EnvironmentSatisfaction  \
# 0                    1               3                        2
# 1                    8               2                        3
# 2                    2               2                        4
# 3                    3               3                        4
# 4                    2               3                        1
# ...                ...             ...                      ...
# 1146                23               4                        3
# 1147                 6               2                        4
# 1148                 4               4                        2
# 1149                 2               2                        4
# 1150                 8               4                        2
#
#       RelationshipSatisfaction
# 0                            1
# 1                            4
# 2                            2
# 3                            3
# 4                            4
# ...                        ...
# 1146                         3
# 1147                         1
# 1148                         2
# 1149                         4
# 1150                         1
#
# [1151 rows x 13 columns]
