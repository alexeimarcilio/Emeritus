# %% [markdown]
# # Correlation

# %% [markdown]
# # Outline
# - Correlation magnitude and sign
# - Correlation vs. Causation (differences, use cases)
# - Correlation in Python

# %% [markdown]
# ## Correlation magnitude and sign

# %% [markdown]
# * Correlation is a number between -1 and 1. A value of 0 means that two numbers are NOT correlated.
# * A value of -1 demonstrates a perfect negative linear association
# * A value of 1 is a perfect positive linear association

# %% [markdown]
# ## Correlation vs. Causation (differences, use cases)

# %% [markdown]
# * Here we are looking at values that are correlated. This makes no assumption of a causal relationship.
# * Causal relationships are best determined through hypothesis testing, creating a controlled setting to determine a causal relationship

# %% [markdown]
# ## Correlation in Python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
df = pd.read_csv("employee_attrition.csv")

# %%
cmap = sns.cm.rocket_r
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot=True, annot_kws={"size":9}, cmap=cmap)

# %%
import pandas as pd
import numpy as np
social = pd.read_csv('social_cleaned.csv')

# %%
#numpy's corrcoef function
np.corrcoef([1,2,3], [61,22,1])
# Out:
# array([[ 1.        , -0.98532928],
#        [-0.98532928,  1.        ]])

# %%
#requires equal dimensions
np.corrcoef([1,2,3], [61,22,1,5])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-8585ffd6148b> in <module>
#       1 #requires equal dimensions
# ----> 2 np.corrcoef([1,2,3], [61,22,1,5])
#
# <__array_function__ internals> in corrcoef(*args, **kwargs)
#
# ~/ds/eme/pro/my_project_env/lib/python3.6/site-packages/numpy/lib/function_base.py in corrcoef(x, y, rowvar, bias, ddof)
#    2524         warnings.warn('bias and ddof have no effect and are deprecated',
#    2525                       DeprecationWarning, stacklevel=3)
# -> 2526     c = cov(x, y, rowvar)
#    2527     try:
#    2528         d = diag(c)
#
# <__array_function__ internals> in cov(*args, **kwargs)
#
# ~/ds/eme/pro/my_project_env/lib/python3.6/site-packages/numpy/lib/function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    2388         if not rowvar and y.shape[0] != 1:
#    2389             y = y.T
# -> 2390         X = np.concatenate((X, y), axis=0)
#    2391
#    2392     if ddof is None:
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 1, the array at index 0 has size 3 and the array at index 1 has size 4

# %%
#correlation of frequency of usage of the internet and age

# %%
#correlation of household income and age
