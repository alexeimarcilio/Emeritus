# %% [markdown]
# # Module 7 Data Visualization
#
# **_Author: Favio Vázquez_**
#
# **Expected time = 2 hours**
#
# **Total points = 100 points**

# %% [markdown]
# ## Assignment Overview
#
# In this assignment you will use matplotlib and pandas to create and customize a number of data visualizations. You will begin by creating a simple line plot and gradually build your skills to create more complex and customized visualizations. You will use pandas to create a pairs plot so you can display multiple scatter plots in one figure. Finally, you will wrap up the assignment by creating a time series visualization in matplotlib. **Please review the Important Instructions section below. You must adhere to these instructions to ensure the grading for this assignment works properly in Vocareum.**
#
# This assignment is designed to build your familiarity and comfort coding in Python while also helping you review key topics from each module. As you progress through the assignment, answers will get increasingly complex. It is important that you adopt a data scientist's mindset when completing this assignment. **Remember to run your code from each cell before submitting your assignment.** Running your code beforehand will notify you of errors and give you a chance to fix your errors before submitting. You should view your Vocareum submission as if you are delivering a final project to your manager or client.
#
# ***Vocareum Tips***
#
# - Do not add arguments or options to functions unless you are specifically asked to. This will cause an error in Vocareum.
# - Do not use a library unless you are expicitly asked to in the question.
#
#
# ### Learning Objectives
#
# - Use matplotlib to visualize data including basic plots and time series.
# - Explain the benefits and limitations of various data visualizations.
# - Examine various data visualization tools.
# - Select the appropriate data visualization to effectively communicate the dataset and analysis.

# %% [markdown]
# **IMPORTANT INSTRUCTIONS:**
#
# - To be able to test for this module, you will be asked to save your figures as PNG into a folder called "results". Please don't change the name we ask you to give to the plots so you are able to get all the points in every question. The code you will use to save the PNG files is: plt.savefig("results/plot.png")
# - Don't add any customization you're not asked to in the plots.

# %% [markdown]
# ## Index:
#
# #### Module 7: Data Visualization.
#
# - [Question 1](#Question-1)
# - [Question 2](#Question-2)
# - [Question 3](#Question-3)
# - [Question 4](#Question-4)
# - [Question 5](#Question-5)
# - [Question 6](#Question-6)
# - [Question 7](#Question-7)
# - [Question 8](#Question-8)
# - [Question 9](#Question-9)
# - [Question 10](#Question-10)

# %%
# Let's start by importing the libraries we will be using
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from dateutil.parser import parse
from sklearn import datasets
import scipy.stats as sp
import math

# Avoid warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Getting started with Matplotlib
#
# You will start by creating some basic plots with matplotlib. You will also label the `Xaxis` and `Yaxis` of your figures.

# %% [markdown]
# [Back to top](#Index:)
#
# ### Question 1
# *5 points*
#
# Use the matplotlib function `plt.plot()` to create a basic lineplot with the data x and y from below. Add a `y-label` using `plt.ylabel()` with the words "numbers y" and add a `x-label` with the words "numbers x" using `plt.xlabel()`.
#
# Save your plot using `plt.savefig` as a png with the name "plot1.png" in the folder "results".

# %%
### GRADED 

# Data
x = [1,2,3,4]
y = [1,2,3,4]

### YOUR SOLUTION HERE
plt.plot(x,y)
plt.ylabel("numbers y")
plt.xlabel("numbers x")
plt.savefig('results/plot1.png')

###
### YOUR CODE HERE
###

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# [Back to top](#Index:)
#
# ### Question 2
# *10 points*
#
# In the code cell below we have defined a vector $t$. Plot, on the same graph, $t$, $t^2$ and $t^3$.
# Set the styleline for the first line to 'ro', the styleline for the second line to 'bs', and the third one to 'g^'.
# Make sure to set the limits for the x axis equal to [0,6], and the limits for the y axis equal to [0-150].
#
# Save your plot as a png with the name "plot2.png" in the folder "results".
#
# **HINT:** Your result should look like the image below:
#
# ![](images/1.png)

# %%
### GRADED 

# Data
t = np.arange(0., 5., 0.2)

### YOUR SOLUTION HERE
plt.plot(t, t, 'ro', t, t**2, 'bs', t, t**3, 'g^');
plt.ylim([0,150])
plt.xlim([0,6])

plt.savefig('results/plot2.png')


###
### YOUR CODE HERE
###

# %%
t
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4,
#        2.6, 2.8, 3. , 3.2, 3.4, 3.6, 3.8, 4. , 4.2, 4.4, 4.6, 4.8])

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# ## Simple line plots
#
# Next, you will create a simple line plot. As you may remember:
# - X-axis requires quantitative variable
# - Y-axis values must be numbers and can be set to be interpreted (formatted) as decimal, percent, and currency.
# - Variables have contiguous values
# - Familiar/conventional ordering among ordinals

# %% [markdown]
# [Back to top](#Index:)
#
# ### Question 3
# *10 points*
#
# Plot the functions $f(x) = \sin(x)$ and $f(x) = 3 \cos(x)$ as a line plot. Costumize the plot as follows:
#
# - Title: "Function plots". **Hint: Notice the capitalization**.
# - y-label = "values"
# - x-label = "angles"
#
# The data `x` is defined for you in the grading cell below.
#
# Save your plot as a png with the name "plot3.png" in the folder "results".

# %%
### GRADED 

# the x axis: ndarray object of angles between 0 and 2π
x = np.arange(0, math.pi*2, 0.05)
plt.plot(x, np.sin(x), x, 3*np.cos(x) )
plt.xlabel("angles")
plt.ylabel("values")
plt.title("Function plots")
plt.savefig('results/plot3.png')

### YOUR SOLUTION HERE

###
### YOUR CODE HERE
###

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# ## Bar plots
#
# Next, you will create standard and multi-series bar plots. Bar graphs are used to compare data between different groups or to track changes over time (similar to a line chart). Multi-series Bar graphs can display multiple groups in the same bar in a stacked visual showing the composition of the bar chart along the Y-axis.
#
# Matplotlib provides the **bar()** function for creating bar plots.
#
# You can use the **bar()** function parameters below with the axes object:
#
# ``plt.bar(x, height, width, bottom, align)``

# %% [markdown]
# [Back to top](#Index:)
#
# ### Question 4
# *5 points*
#
# Given the data `y_pos` and `height` below, use the function `bar()` to create a bar plot. Set the argument `color` inside the function `bar()` equal to `(0.2, 0.4, 0.6, 0.6)`. Make these customizations to the plot:
#
# - Title: "My bar plot"
# - X-ticks: Use (y_pos, bars) as arguments for `plt.xticks`.
#
# Save your plot as a png with the name "plot4.png" in the folder "results".

# %%
### GRADED 

# Data
height = [3, 12, 5, 18, 45]
bars = ('A', 'B', 'C', 'D', 'E')
y_pos = np.arange(len(bars))

### YOUR SOLUTION HERE
plt.bar(bars, height, color=(0.2, 0.4, 0.6, 0.6))
plt.title("My bar plot")
plt.xticks(y_pos, bars);
plt.savefig('results/plot4.png')

###
### YOUR CODE HERE
###

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# [Back to top](#Index:)
#
# ### Question 5
# *20 points*
#
# Given the data below `r1` and `bars1` create a first bar plot by making sure you set the following parameters:
# - The first bar should be created with the arguments `width=bar_width`, `color='blue'`, `edgecolor='black'`, `yerr=yer1`, `capsize=7`, `label='group1'`.
#
# Next, given the data below `r2` and `bars2` create a second bar plot by making sure you set the following parameters:
# - The second bar should be created with the arguments `width=bar_width`, `color='cyan'`, `edgecolor='black'`, `yerr=yer2`, `capsize=7`,`label='group12'`.
#
# Finally, use the appropraite function to set the following parameters:
# - Title: "Advanced bar plot".
# - Y-label = "height".
# - Legend = Show a standard label with the name of the bars. **Hint: Use the function `plt.legend()` to show the legend.**
#
# Save your plot as a png with the name "plot5.png" in the folder "results".
#
# The final plot should look like this:
#
# <center>
# <img src = images/2.png height = 300 width = 400 />
# </center>

# %%
### GRADED 

# Data

# width of the bars
bar_width = 0.3
 
# Choose the height of the blue bars
bars1 = [10, 9, 2]
 
# Choose the height of the cyan bars
bars2 = [10.8, 9.5, 4.5]
 
# Choose the height of the error bars (bars1)
yer1 = [0.5, 0.4, 0.5]
 
# Choose the height of the error bars (bars2)
yer2 = [1, 0.7, 1]

# The x position of bars
r1 = np.arange(len(bars1))
r2 = [x + bar_width for x in r1]

# general layout
plt.xticks([r + bar_width for r in range(len(bars1))], ['cond_A', 'cond_B', 'cond_C'])


### YOUR SOLUTION HERE
plt.bar(r1, bars1, width=bar_width, color='blue', edgecolor='black', yerr=yer1, capsize=7, label='group1')
plt.bar(r2, bars2, width=bar_width, color='cyan', edgecolor='black', yerr=yer2, capsize=7,label='group12')

plt.title("Advanced bar plot")
plt.ylabel("height")
plt.legend()
plt.savefig('results/plot5.png')
###
### YOUR CODE HERE
###

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# ## Histograms
# A histogram is a display of statistical information that uses rectangles to show the frequency of data items in successive numerical intervals of equal size. In the most common form of histogram, the **independent** variable is plotted along the horizontal axis and the **dependent** variable is plotted along the vertical axis.
#
# Matplotlib provides the **plt.hist()** function for creating histograms plots.
#
# You can use the **plt.hist()** function parameters below with the axes object:
#
# ``plt.hist(x_values, bins, color, transparency)``

# %% [markdown]
# [Back to top](#Index:)
#
# ### Question 6
# *10 points*
#
# Use the NumPy functions `np.random.randn` to generate data `x` for a normal distribution for 100,000 points.
# Then plot a histogram for `x` by setting the parameter `bins = n_bins`.
#
# Note that we have defined for you the variables `np-random.seed`, `N_points` and `n_bins`
#
# Save your plot as a png with the name "plot6.png" in the folder "results".

# %%
### GRADED 

np.random.seed(123)
N_points = 100000
n_bins = 20

### YOUR SOLUTION HERE
x = np.random.randn(100000)
plt.hist(x, bins = n_bins)
plt.savefig('results/plot6.png')
###
### YOUR CODE HERE
###

# %%
len(x)
# Out:
# 100000

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# [Back to top](#Index:)
#
# ### Question 7
# *15 points*
#
# Given the data below, create a histogram using the data `x` and the number of bins given (`num_bins`) and by setting the arguments `density=1`, `facecolor=red`, and `alpha=0.6`.
#
# The pseudocde for this part is given below:
#
# ```Python
# #complete the arguments inside hist() as directed
# n, bins, patches = plt.hist(   )
#
# ```
#
# Use the `scipy` function `.norm.pdf()` to create a fitted line to the histogram by choosing the parameters `bins` (just computed) and the parameters `mu` and `sigma` we have defined for you. (**HINT**: to render mathematical symbols in a title we can use `$\mu$` and `$\sigma$` in the string to get LaTeX formatting.)
#
# Finally, use the function `plt.plot()` to plot the fitted line. This fit line should be a blue dotted line.
#
#
# Set these customizations to your plot:
#
# - Title = "Histogram of IQ: $\mu=120$, $\sigma=12$"
# - X-label = 'x-axis'
# - Y-label = 'y-axis'
#
# Save your plot as a png with the name "plot7.png" in the folder "results".
#
# The final plot should look like this:
#
# <center>
# <img src = images/4.png height = 300 width = 400 />
# </center>

# %%
### GRADED

# Data
np.random.seed(123)
mu = 120 # mean of distribution
sigma = 12 # standard deviation of distribution
x = mu + sigma * np.random.randn(10000)
num_bins = 20

### YOUR SOLUTION HERE
n, bins, patches = plt.hist(x, num_bins, density=1, facecolor='red', alpha=0.6)

y = sp.norm.pdf(bins, mu, sigma)
plt.plot(bins, y, 'b--')

# add in our labels and title
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title(r'Histogram of IQ: $\mu=120$, $\sigma=12$')

plt.savefig('results/plot7.png')
###
### YOUR CODE HERE
###

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# ## Box plots
#
# A box plot is a plot that displays a summary of a set of data containing the minimum, first quartile, median, third quartile, and maximum. In a box plot, we draw a box from the first quartile to the third quartile. A vertical line goes through the box at the median. The whiskers go from each quartile to the minimum or maximum.
#
# We will use the `boxplot()` function to create a boxplot with Matplotlib. Parameters in the `boxplot()` function determine orientation, colors, labels for the figure.

# %% [markdown]
# [Back to top](#Index:)
#
# ### Question 8
# *10 points*
#
# Using the data `data` below, create a box plot by using the function `plt.boxplot()`. To plot the outliers, set the parameter `flierprops` equal to `green_diamond`.
#
# Make these customizations to your final plot:
#
# - Title: "My box plot"
# - X-label: "data"
#
#
# Save your plot as a png with the name "plot8.png" in the folder "results".

# %%
### GRADED

# Data
np.random.seed(123)
spread = np.random.rand(50) * 100
center = np.ones(25) * 50
flier_high = np.random.rand(10) * 100 + 100
flier_low = np.random.rand(10) * -100
data = np.concatenate((spread, center, flier_high, flier_low))

# For outliers
green_diamond = dict(markerfacecolor='g', marker='D')

### YOUR SOLUTION HERE
fig = plt.figure()
# Create an axes instance
ax = fig.add_axes([0,0,1,1])
# Create the boxplot
plt.boxplot(data, flierprops=green_diamond)
# Display
#plt.show()
plt.title("My box plot")
plt.xlabel("data")
plt.savefig('results/plot8.png')
###
### YOUR CODE HERE
###

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# ## Pair plots
#
# A “pairs plot” is also known as a scatter matrix. A scatter matrix is a collection of scatterplots organized into a grid (or matrix). Each scatterplot shows the relationship between a pair of variables. Plots are just elaborations on this, showing all variables paired with all the other variables.
#
# Here, you will create a pairs plot using pandas.

# %% [markdown]
# [Back to top](#Index:)
#
# ### Question 9
# *10 points*
#
# Create a pair plot of `iris_dataframe` using the pandas function `scatter_matrix` from the `plotting` module. Use these customizations inside the `pd.plotting.scatter_matrix` function:
#
# ```
# c = Y
# figsize = (15,15)
# marker = 'o'
# hist_kwds={'bins':20}
# s = 60
# alpha = 0.8
# ```
#
# Save your plot as a png with the name "plot9.png" in the folder "results".

# %%
### GRADED

# Data
iris_dataset = datasets.load_iris()
X = iris_dataset.data
Y = iris_dataset.target

iris_dataframe = pd.DataFrame(X, columns=iris_dataset.feature_names)

### YOUR SOLUTION HERE
pd.plotting.scatter_matrix(iris_dataframe, c = Y, figsize = (15,15), marker = 'o', 
                           hist_kwds={'bins':20},
                           s = 60,
                           alpha = 0.8);

plt.savefig('results/plot9.png')
###
### YOUR CODE HERE
###

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# ## Time series
# A Time Series plot in matplotlib is, in essence, a special case of a line plot. That is, we are plotting x and y points connected by a line by using the command `plot()`, however, the x coordinates represent ``time``.

# %% [markdown]
# [Back to top](#Index:)
#
# ### Question 10
# *5 points*
#
# For the time series data `ts` given below, create a lineplot using the *series `.plot` method*. Change the title of the plot to 'My time series'.
#
# Save your plot as a png with the name "plot10.png" in the folder "results".

# %%
### GRADED

# Data
df = pd.read_csv('https://github.com/selva86/datasets/raw/master/AirPassengers.csv')
dates = pd.DatetimeIndex([parse(d).strftime('%Y-%m-01') for d in df['date']])
df.set_index(dates, inplace=True)

# convert the dataframe into a Series, there is only one column
ts = df['value']


### YOUR SOLUTION HERE
ts.plot()
plt.title('My time series')
plt.savefig('results/plot10.png')
###
### YOUR CODE HERE
###

# %%
ts
# Out:
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
#              ...
# 1960-08-01    606
# 1960-09-01    508
# 1960-10-01    461
# 1960-11-01    390
# 1960-12-01    432
# Name: value, Length: 144, dtype: int64

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# ## Office Hour with Pol

# %% [markdown]
# People these days are using Seaborn. <br>
# There's also ggplot2 for python. That's cool. <br>
# Interactive graphics also using bokeh, or plotly.

# %% [markdown]
# **python-graph-gallery.com**

# %%
# library & dataset
import seaborn as sns
df = sns.load_dataset('iris')
 
# Custom the inside plot: options are: “scatter” | “reg” | “resid” | “kde” | “hex”
sns.jointplot(x=df["sepal_length"], y=df["sepal_width"], kind='scatter')
sns.jointplot(x=df["sepal_length"], y=df["sepal_width"], kind='hex')
sns.jointplot(x=df["sepal_length"], y=df["sepal_width"], kind='kde')

# %%
# create data
n = 1000
x = np.arange(n)
y = np.cumsum(np.random.randn(n))
# Out:
# Text(0, 0, 'start')

# %%
y2 = np.cumsum(np.random.randn(n))

plt.plot(x,y)
plt.plot(x, y2)

plt.text(0, 5, 'start')

# Optional format
plt.title("Example Plot")

plt.xlabel('X')
plt.xlabel('Y')

plt.legend(['y', 'y2'])

# %% [markdown]
# ## Barplot

# %%
k = 6 # Sides
n = 1000 # number of rolls

rolls = pd.Series(np.random.randint(k, size = int(n * 0.9)))\
.append(pd.Series(np.repeat(2, int(n * 0.1))))

# %%
fig, ax = plt.subplots()
width = 0.4
ax.bar(rolls.index - (width/2), rolls, width=width)
# Out:
# <BarContainer object of 1000 artists>

# %% [markdown]
# ## Scatterplot

# %%
n = 100
x = np.random.uniform(size =n)
y = x + np.random.randn(n)/10

plt.scatter(x, y)

from sklearn.linear_model import LinearRegression
model = LinearRegression()
x_array = x.reshape((n, 1))

# Easier way:
z = np.polyfit(x, y, 1)
p= np.poly1d(z)
plt.plot(x, p(x), 'r')

# %%
import numpy as np
# set the seed for the random function
np.random.seed(10)
# generate the sample sets: numpy.random.normal(loc=0.0, scale=1.0, size=None)
set_1 = np.random.normal(100, 10, 200)
set_2 = np.random.normal(80, 30, 200)
set_3 = np.random.normal(90, 20, 200)
set_4 = np.random.normal(70, 25, 200)
# create a collection of data to plot (list of ndarray)
data_to_plot = [set_1, set_2, set_3, set_4]

# %%
# create a boxplot from the same data 
box=plt.boxplot(data_to_plot,vert=0,patch_artist=True,labels=['series1','series2','series3','series4'])
# select the colors for the boxes 
colors = ['cyan', 'blue', 'green', 'orange']
# assign the box colors
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)
# display the box plot 
plt.show()
