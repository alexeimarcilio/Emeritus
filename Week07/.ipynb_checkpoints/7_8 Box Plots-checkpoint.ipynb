# %% [markdown]
# # Box Plots
#
# ## Outine
# - What is a Box plot
# - Data set for a Box plot
# - Creating the Box plot
# - Customizing the Box plot
# - Wrapping up

# %% [markdown]
#
#  ### Definition of a Box Plot
#
# A **box plot** which is also known as a whisker plot displays a summary of a set of data containing the minimum, first quartile, median, third quartile, and maximum. In a box plot, we draw a box from the first quartile to the third quartile. A vertical line goes through the box at the median. The whiskers go from each quartile to the minimum or maximum.
#
# <img src="images/box_plot.jpg" width="300">

# %% [markdown]
# ## Data for a Box plot
#
# We will use randomly generated data for the data set. As you recall, **numpy** can provide these types of functions. In this case we will use the ``random.normal()`` function to randomly generate the data from a normal (Gaussian) distribution.
#
# We will be using 200 samples in our data set (per set).

# %%
# import numpy 
import numpy as np
# set the seed for the random function
np.random.seed(10)
# generate the sample sets: numpy.random.normal(loc=0.0, scale=1.0, size=None)
set_1 = np.random.normal(100, 10, 200)
set_2 = np.random.normal(80, 30, 200)
set_3 = np.random.normal(90, 20, 200)
set_4 = np.random.normal(70, 25, 200)
# create a collection of data to plot (list of ndarray)
data_to_plot = [set_1, set_2, set_3, set_4]

# %% [markdown]
# ## Creating the Box plot
# We will use the ``boxplot`` function with the data that we created to create our box plot.
#
# Notice a few things:
# - first, we define a figure and add an axes
# - second, we call the boxplot function with the data
# - third, we display the figure

# %%
plt.style.use('fivethirtyeight')
#plt.style.use('default')

# include pyplot
import matplotlib.pyplot as plt
# create a figure
fig = plt.figure()
# Create an axes instance
ax = fig.add_axes([0,0,1,1])
# Create the boxplot
bp = ax.boxplot(data_to_plot)
# Display
plt.show()

# %% [markdown]
# ## Customizing the Box Plot and displaying it horizontally
#
# Here we will customize the box plot and draw it horiziontally.
#
# Notice the parameters in the boxplot() function:
# - vert = 0 means vertical display is false, or horizontal
# - patch_atrist = True changes the renderer for the boxes, in this case to set color, it muse be True
# - labels allow us to label the data series
# - also notice, patch.set_facecolor() sets the color of the boxplot boxes

# %%
# create a boxplot from the same data 
box=plt.boxplot(data_to_plot,vert=0,patch_artist=True,labels=['series1','series2','series3','series4'])
# select the colors for the boxes 
colors = ['cyan', 'blue', 'green', 'orange']
# assign the box colors
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)
# display the box plot 
plt.show()

# %% [markdown]
# ## Wrapping up
# We covered:
# - What is a Box plot
# - Creating the Box plot
# - Customizing the Box plot
#
# For more examples of box plots, see the Matplotlib gallery:
#
# https://matplotlib.org/3.1.1/gallery/index.html

# %% [markdown]
# ## My Work

# %%
a = ("John", "Charles", "Mike")
b = ("Jenny", "Christy", "Monica")

x = zip(a, b)

# %%
print(tuple(x))
# Out:
# (('John', 'Jenny'), ('Charles', 'Christy'), ('Mike', 'Monica'))

# %%
x = [x for x in range(0,10)]

# %%
y = [y**2 for y in x]

# %%
y
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
plt.plot(x, y, c='pink', lw=10, );

# %%
height = [3,12,5,18,45]
bar = (('A','B','C','D','E'))
bars = np.arange(len(bars))

plt.xlabel("X")
plt.xticks = bar

plt.bar(bar, height)
# Out:
# <BarContainer object of 5 artists>

# %%
import seaborn as sns
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.stripplot(tips['total_bill'], jitter=True)

# %%
sns.boxplot(tips['sex'], tips['total_bill'])

# %%
tips['sex'].value_counts().plot()

# %%
plt.plot([1,2,4],[5,4,3])

# %%
plt.style.use('default')
fig, ax = plt.subplots(2,2)
ax[0,0].plot(tips['tip'])
plt.tight_layout()
ax[1,1].boxplot(tips['tip'])
sns.countplot(tips['day'], hue = tips['sex'], ax=ax[0,1])

# %%
plt.show()

# %%
def width_finder(x):
    plt.bar(tips['sex'], tips['tip'], hatch = 'x', width=width)

# %%
interact(width_finder, width = widgets.FloatSlider(min=0.01, max = 3))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-116-e99838b03b67> in <module>
# ----> 1 interact(width_finder, width = widgets.FloatSlider(min=0.01, max = 3))
#
# ~/ds/eme/pro/my_project_env/lib/python3.6/site-packages/ipywidgets/widgets/interaction.py in __call__(self, _InteractFactory__interact_f, **kwargs)
#     526         #    def f(*args, **kwargs):
#     527         #        ...
# --> 528         w = self.widget(f)
#     529         try:
#     530             f.widget = w
#
# ~/ds/eme/pro/my_project_env/lib/python3.6/site-packages/ipywidgets/widgets/interaction.py in widget(self, f)
#     442             The function to which the interactive widgets are tied.
#     443         """
# --> 444         return self.cls(f, self.opts, **self.kwargs)
#     445
#     446     def __call__(self, __interact_f=None, **kwargs):
#
# ~/ds/eme/pro/my_project_env/lib/python3.6/site-packages/ipywidgets/widgets/interaction.py in __init__(self, _interactive__interact_f, _interactive__options, **kwargs)
#     186         self.auto_display = __options.get("auto_display", False)
#     187
# --> 188         new_kwargs = self.find_abbreviations(kwargs)
#     189         # Before we proceed, let's make sure that the user has passed a set of args+kwargs
#     190         # that will lead to a valid call of the function. This protects against unspecified
#
# ~/ds/eme/pro/my_project_env/lib/python3.6/site-packages/ipywidgets/widgets/interaction.py in find_abbreviations(self, kwargs)
#     286             for name, value, default in _yield_abbreviations_for_parameter(param, kwargs):
#     287                 if value is empty:
# --> 288                     raise ValueError('cannot find widget or abbreviation for argument: {!r}'.format(name))
#     289                 new_kwargs.append((name, value, default))
#     290         return new_kwargs
#
# ValueError: cannot find widget or abbreviation for argument: 'x'

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
def f(x):
    return x

# %%
interact(f, x=10);
# Out:
# interactive(children=(IntSlider(value=10, description='x', max=30, min=-10), Output()), _dom_classes=('widget-…
